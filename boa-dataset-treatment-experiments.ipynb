# %%
# Cloner le dépôt
# !git clone https://github.com/vleonel-junior/BOA-dataset-treatment.git
# Out:
# Cloning into 'BOA-dataset-treatment'...
# remote: Enumerating objects: 716, done.
# remote: Counting objects: 100% (106/106), done.
# remote: Compressing objects: 100% (68/68), done.
# remote: Total 716 (delta 54), reused 84 (delta 34), pack-reused 610 (from 1)
# Receiving objects: 100% (716/716), 31.87 MiB | 31.11 MiB/s, done.
# Resolving deltas: 100% (345/345), done.

# %%
# Changer le répertoire de travail
import os
os.chdir('/kaggle/working/BOA-dataset-treatment')

# %%
# Vérifier le répertoire et les fichiers
# !pwd
# !ls -la
# Out:
# /kaggle/working/BOA-dataset-treatment
# total 412
# drwxr-xr-x 8 root root   4096 Sep  6 15:40 .
# drwxr-xr-x 3 root root   4096 Sep  6 15:40 ..
# -rw-r--r-- 1 root root  18029 Sep  6 15:40 attention_analysis_main.py
# -rw-r--r-- 1 root root 295267 Sep  6 15:40 boa-dataset-treatment-experiments.ipynb
# drwxr-xr-x 3 root root   4096 Sep  6 15:40 data
# drwxr-xr-x 2 root root   4096 Sep  6 15:40 example
# drwxr-xr-x 8 root root   4096 Sep  6 15:40 .git
# -rw-r--r-- 1 root root     68 Sep  6 15:40 .gitignore
# -rw-r--r-- 1 root root  12427 Sep  6 15:40 load_pretrained_attention_models.py
# drwxr-xr-x 2 root root   4096 Sep  6 15:40 mgs_grf
# -rw-r--r-- 1 root root   7961 Sep  6 15:40 prepare_from_Xy.py
# drwxr-xr-x 3 root root   4096 Sep  6 15:40 rtdl
# -rw-r--r-- 1 root root  29675 Sep  6 15:40 rtdl_attention_models.py
# drwxr-xr-x 6 root root   4096 Sep  6 15:40 rtdl_revisiting_models
# -rw-r--r-- 1 root root   1494 Sep  6 15:40 test_attention_analysis.py
# ...

# %%
# Installer les dépendances
# !pip install "scikit-learn>=1.0,<2" -qqq > /dev/null 2>&1 && echo 'Installation de scikit-learn réussie'
# !pip install libzero==0.0.4 -qqq > /dev/null 2>&1 && echo 'Installation de libzero réussie'
# !pip install optuna -qqq > /dev/null 2>&1 && echo 'Installation de optuna réussie'
# !pip install sparsemax -qqq > /dev/null 2>&1 && echo 'Installation de sparsemax réussie'
# !pip install icecream -qqq > /dev/null 2>&1 && echo 'Installation de icecream réussie'
# !pip install pytomlpp -qqq > /dev/null 2>&1 && echo 'Installation de pytomlpp réussie'
# Out:
# Installation de scikit-learn réussie
# Installation de libzero réussie
# Installation de optuna réussie
# Installation de sparsemax réussie
# Installation de icecream réussie
# Installation de pytomlpp réussie

# %%
# Créer le dossier results/ si absent
# !mkdir -p results

# %% [markdown]
# # *Générer les checkpoints*

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
import torch
print("CUDA disponible :", torch.cuda.is_available())
print("Indice du GPU :", torch.cuda.current_device())
print("Nom du GPU :", torch.cuda.get_device_name(torch.cuda.current_device()))
# Out:
# CUDA disponible : True
# Indice du GPU : 0
# Nom du GPU : Tesla P100-PCIE-16GB

# %% [markdown]
# ### *Je crois qu'en ce qui concerne le test de permutation, nous allons nous concentrer que sur les datasets disposant uniquement de variables continues. Et donc cela au détriment de datasets comme Adults ou celle de la BOA possédant des variables catégorielles*.

# %% [markdown]
# ## *California Housing*

# %%
# California Housing - FT-Transformer attention
# !for seed in {0..4}; do echo "Entraînement FT-Transformer pour seed $seed"; python -m rtdl_revisiting_models.bin.ft_transformer_attention -f /kaggle/working/BOA-dataset-treatment/rtdl_revisiting_models/output/california_housing/ft_transformer_attention/default/$seed.toml; done
# Out:
# Entraînement FT-Transformer pour seed 0
# ...
# Config: /kaggle/working/BOA-dataset-treatment/rtdl_revisiting_models/output/california_housing/ft_transformer_attention/default/0.toml
# Output: /kaggle/working/BOA-dataset-treatment/rtdl_revisiting_models/output/california_housing/ft_transformer_attention/default/0
# ...
# Creating the output...
# Using cached X: /kaggle/working/BOA-dataset-treatment/rtdl_revisiting_models/data/california_housing/build_X__quantile__mean__new__indices__0.pickle
# Création du modèle FTTransformer avec extraction d'attention...
#   0%|                                           | 0/52000000000 [00:00<?, ?it/s]
# >>> Epoch 1 | 0:00:00 | /kaggle/working/BOA-dataset-treatment/rtdl_revisiting_models/output/california_housing/ft_transformer_attention/default/0
# lr = 0.0001 | batch_size = 256 | chunk_size = None | epoch_size = 52 | n_parameters = 893179
#   0%|                           | 49/52000000000 [00:00<187844:18:02, 76.90it/s][train] loss = 0.404
# ...

# %%
# California Housing - Sparse FTT+ attention 
# !for seed in {0..4}; do echo "Entraînement Sparse FTT+ pour seed $seed"; python -m rtdl_revisiting_models.bin.sparse_ftt_plus_attention -f /kaggle/working/BOA-dataset-treatment/rtdl_revisiting_models/output/california_housing/sparse_ftt_plus_attention/default/$seed.toml; done
# Out:
# Entraînement Sparse FTT+ pour seed 0
# ...
# Config: /kaggle/working/BOA-dataset-treatment/rtdl_revisiting_models/output/california_housing/sparse_ftt_plus_attention/default/0.toml
# Output: /kaggle/working/BOA-dataset-treatment/rtdl_revisiting_models/output/california_housing/sparse_ftt_plus_attention/default/0
# ...
# Creating the output...
# Using cached X: /kaggle/working/BOA-dataset-treatment/rtdl_revisiting_models/data/california_housing/build_X__quantile__mean__new__indices__0.pickle
# Création du modèle SparseFTTPlus avec extraction d'attention...
#   0%|                                           | 0/52000000000 [00:00<?, ?it/s]
# >>> Epoch 1 | 0:00:00 | /kaggle/working/BOA-dataset-treatment/rtdl_revisiting_models/output/california_housing/sparse_ftt_plus_attention/default/0
# lr = 0.0001 | batch_size = 256 | chunk_size = None | epoch_size = 52 | n_parameters = 893179
#   0%|                           | 49/52000000000 [00:00<214338:03:06, 67.39it/s][train] loss = 0.364
# ...

# %% [markdown]
# ## *Helena*

# %%
# Helena - FT-Transformer
# !for seed in {0..4}; do echo "Entraînement FT-Transformer pour seed $seed"; python -m rtdl_revisiting_models.bin.ft_transformer_attention -f /kaggle/working/BOA-dataset-treatment/rtdl_revisiting_models/output/helena/ft_transformer_attention/default/$seed.toml; done
# Out:
# Entraînement FT-Transformer pour seed 0
# ...
# Config: /kaggle/working/BOA-dataset-treatment/rtdl_revisiting_models/output/helena/ft_transformer_attention/default/0.toml
# Output: /kaggle/working/BOA-dataset-treatment/rtdl_revisiting_models/output/helena/ft_transformer_attention/default/0
# ...
# Creating the output...
# Création du modèle FTTransformer avec extraction d'attention...
#   0%|                                           | 0/82000000000 [00:00<?, ?it/s]
# >>> Epoch 1 | 0:00:00 | /kaggle/working/BOA-dataset-treatment/rtdl_revisiting_models/output/helena/ft_transformer_attention/default/0
# lr = 0.0001 | batch_size = 512 | chunk_size = None | epoch_size = 82 | n_parameters = 919582
#   0%|                           | 80/82000000000 [00:03<806232:10:42, 28.25it/s][train] loss = 3.953
# ...

# %%
# Helena - Sparse FTT+
# !for seed in {0..4}; do echo "Entraînement Sparse FTT+ pour seed $seed"; python -m rtdl_revisiting_models.bin.sparse_ftt_plus_attention -f /kaggle/working/BOA-dataset-treatment/rtdl_revisiting_models/output/helena/sparse_ftt_plus_attention/default/$seed.toml; done
# Out:
# Entraînement Sparse FTT+ pour seed 0
# ...
# Config: /kaggle/working/BOA-dataset-treatment/rtdl_revisiting_models/output/helena/sparse_ftt_plus_attention/default/0.toml
# Output: /kaggle/working/BOA-dataset-treatment/rtdl_revisiting_models/output/helena/sparse_ftt_plus_attention/default/0
# ...
# Creating the output...
# Using cached X: /kaggle/working/BOA-dataset-treatment/rtdl_revisiting_models/data/helena/build_X__standard__mean__new__indices__0.pickle
# Création du modèle SparseFTTPlus avec extraction d'attention...
#   0%|                                           | 0/82000000000 [00:00<?, ?it/s]
# >>> Epoch 1 | 0:00:00 | /kaggle/working/BOA-dataset-treatment/rtdl_revisiting_models/output/helena/sparse_ftt_plus_attention/default/0
# lr = 0.0001 | batch_size = 512 | chunk_size = None | epoch_size = 82 | n_parameters = 919582
#   0%|                          | 80/82000000000 [00:04<1175302:07:12, 19.38it/s][train] loss = 3.976
# ...

# %% [markdown]
# ## *Jannis*

# %%
# Jannis - FT-Transformer
# !for seed in {0..4}; do echo "Entraînement FT-Transformer pour seed $seed"; python -m rtdl_revisiting_models.bin.ft_transformer_attention -f /kaggle/working/BOA-dataset-treatment/rtdl_revisiting_models/output/jannis/ft_transformer_attention/default/$seed.toml; done
# Out:
# Entraînement FT-Transformer pour seed 0
# ...
# Config: /kaggle/working/BOA-dataset-treatment/rtdl_revisiting_models/output/jannis/ft_transformer_attention/default/0.toml
# Output: /kaggle/working/BOA-dataset-treatment/rtdl_revisiting_models/output/jannis/ft_transformer_attention/default/0
# ...
# Creating the output...
# Création du modèle FTTransformer avec extraction d'attention...
#   0%|                                          | 0/105000000000 [00:00<?, ?it/s]
# >>> Epoch 1 | 0:00:00 | /kaggle/working/BOA-dataset-treatment/rtdl_revisiting_models/output/jannis/ft_transformer_attention/default/0
# lr = 0.0001 | batch_size = 512 | chunk_size = None | epoch_size = 105 | n_parameters = 911422
#   0%|                        | 103/105000000000 [00:06<1909856:28:19, 15.27it/s][train] loss = 0.871
# ...

# %%
# Jannis - Sparse FTT+
# !for seed in {0..4}; do echo "Entraînement Sparse FTT+ pour seed $seed"; python -m rtdl_revisiting_models.bin.sparse_ftt_plus_attention -f /kaggle/working/BOA-dataset-treatment/rtdl_revisiting_models/output/jannis/sparse_ftt_plus_attention/default/$seed.toml; done
# Out:
# Entraînement Sparse FTT+ pour seed 0
# ...
# Config: /kaggle/working/BOA-dataset-treatment/rtdl_revisiting_models/output/jannis/sparse_ftt_plus_attention/default/0.toml
# Output: /kaggle/working/BOA-dataset-treatment/rtdl_revisiting_models/output/jannis/sparse_ftt_plus_attention/default/0
# ...
# Creating the output...
# Using cached X: /kaggle/working/BOA-dataset-treatment/rtdl_revisiting_models/data/jannis/build_X__quantile__mean__new__indices__0.pickle
# Création du modèle SparseFTTPlus avec extraction d'attention...
#   0%|                                          | 0/105000000000 [00:00<?, ?it/s]
# >>> Epoch 1 | 0:00:00 | /kaggle/working/BOA-dataset-treatment/rtdl_revisiting_models/output/jannis/sparse_ftt_plus_attention/default/0
# lr = 0.0001 | batch_size = 512 | chunk_size = None | epoch_size = 105 | n_parameters = 911422
#   0%|                        | 104/105000000000 [00:17<4967615:11:51,  5.87it/s][train] loss = 0.898
# ...

# %% [markdown]
# ## *Higgs Small*

# %%
# Higgs Small - FT-Transformer
# !for seed in {0..4}; do echo "Entraînement FT-Transformer pour seed $seed"; python -m rtdl_revisiting_models.bin.ft_transformer_attention -f /kaggle/working/BOA-dataset-treatment/rtdl_revisiting_models/output/higgs_small/ft_transformer_attention/default/$seed.toml; done
# Out:
# Entraînement FT-Transformer pour seed 0
# ...
# Config: /kaggle/working/BOA-dataset-treatment/rtdl_revisiting_models/output/higgs_small/ft_transformer_attention/default/0.toml
# Output: /kaggle/working/BOA-dataset-treatment/rtdl_revisiting_models/output/higgs_small/ft_transformer_attention/default/0
# ...
# Creating the output...
# Création du modèle FTTransformer avec extraction d'attention...
#   0%|                                          | 0/123000000000 [00:00<?, ?it/s]
# >>> Epoch 1 | 0:00:00 | /kaggle/working/BOA-dataset-treatment/rtdl_revisiting_models/output/higgs_small/ft_transformer_attention/default/0
# lr = 0.0001 | batch_size = 512 | chunk_size = None | epoch_size = 123 | n_parameters = 900859
#   0%|                        | 121/123000000000 [00:04<1278656:58:40, 26.72it/s][train] loss = 0.608
# [val  ] score = 0.695 | acc = 0.695 | mf1 = 0.695 | ms = 15688 | wf1 = 0.695 | ws = 15688 | roc_auc = 0.768
# ...

# %%
# Higgs Small - Sparse FTT+
# !for seed in {0..4}; do echo "Entraînement Sparse FTT+ pour seed $seed"; python -m rtdl_revisiting_models.bin.sparse_ftt_plus_attention -f /kaggle/working/BOA-dataset-treatment/rtdl_revisiting_models/output/higgs_small/sparse_ftt_plus_attention/default/$seed.toml; done
# Out:
# Entraînement Sparse FTT+ pour seed 0
# ...
# Config: /kaggle/working/BOA-dataset-treatment/rtdl_revisiting_models/output/higgs_small/sparse_ftt_plus_attention/default/0.toml
# Output: /kaggle/working/BOA-dataset-treatment/rtdl_revisiting_models/output/higgs_small/sparse_ftt_plus_attention/default/0
# ...
# Creating the output...
# Using cached X: /kaggle/working/BOA-dataset-treatment/rtdl_revisiting_models/data/higgs_small/build_X__quantile__mean__new__indices__0.pickle
# Création du modèle SparseFTTPlus avec extraction d'attention...
#   0%|                                          | 0/123000000000 [00:00<?, ?it/s]
# >>> Epoch 1 | 0:00:00 | /kaggle/working/BOA-dataset-treatment/rtdl_revisiting_models/output/higgs_small/sparse_ftt_plus_attention/default/0
# lr = 0.0001 | batch_size = 512 | chunk_size = None | epoch_size = 123 | n_parameters = 900859
#   0%|                        | 121/123000000000 [00:07<1929435:19:36, 17.71it/s][train] loss = 0.612
# ...

# %% [markdown]
# # *Vérifier les checkpoints*

# %%
# california_housing
# !ls /kaggle/working/BOA-dataset-treatment/rtdl_revisiting_models/output/california_housing/ft_transformer_attention/default/*/checkpoint.pt || echo "Aucun checkpoint trouvé"
# !ls /kaggle/working/BOA-dataset-treatment/rtdl_revisiting_models/output/california_housing/sparse_ftt_plus_attention/default/*/checkpoint.pt || echo "Aucun checkpoint trouvé"
# Out:
# /kaggle/working/BOA-dataset-treatment/rtdl_revisiting_models/output/california_housing/ft_transformer_attention/default/0/checkpoint.pt
# /kaggle/working/BOA-dataset-treatment/rtdl_revisiting_models/output/california_housing/ft_transformer_attention/default/1/checkpoint.pt
# /kaggle/working/BOA-dataset-treatment/rtdl_revisiting_models/output/california_housing/ft_transformer_attention/default/2/checkpoint.pt
# /kaggle/working/BOA-dataset-treatment/rtdl_revisiting_models/output/california_housing/ft_transformer_attention/default/3/checkpoint.pt
# /kaggle/working/BOA-dataset-treatment/rtdl_revisiting_models/output/california_housing/ft_transformer_attention/default/4/checkpoint.pt
# /kaggle/working/BOA-dataset-treatment/rtdl_revisiting_models/output/california_housing/sparse_ftt_plus_attention/default/0/checkpoint.pt
# /kaggle/working/BOA-dataset-treatment/rtdl_revisiting_models/output/california_housing/sparse_ftt_plus_attention/default/1/checkpoint.pt
# ...

# %%
# helena
# !ls /kaggle/working/BOA-dataset-treatment/rtdl_revisiting_models/output/helena/ft_transformer_attention/default/*/checkpoint.pt || echo "Aucun checkpoint trouvé"
# !ls /kaggle/working/BOA-dataset-treatment/rtdl_revisiting_models/output/helena/sparse_ftt_plus_attention/default/*/checkpoint.pt || echo "Aucun checkpoint trouvé"
# Out:
# /kaggle/working/BOA-dataset-treatment/rtdl_revisiting_models/output/helena/ft_transformer_attention/default/0/checkpoint.pt
# /kaggle/working/BOA-dataset-treatment/rtdl_revisiting_models/output/helena/ft_transformer_attention/default/1/checkpoint.pt
# /kaggle/working/BOA-dataset-treatment/rtdl_revisiting_models/output/helena/ft_transformer_attention/default/2/checkpoint.pt
# /kaggle/working/BOA-dataset-treatment/rtdl_revisiting_models/output/helena/ft_transformer_attention/default/3/checkpoint.pt
# /kaggle/working/BOA-dataset-treatment/rtdl_revisiting_models/output/helena/ft_transformer_attention/default/4/checkpoint.pt
# /kaggle/working/BOA-dataset-treatment/rtdl_revisiting_models/output/helena/sparse_ftt_plus_attention/default/0/checkpoint.pt
# /kaggle/working/BOA-dataset-treatment/rtdl_revisiting_models/output/helena/sparse_ftt_plus_attention/default/1/checkpoint.pt
# ...

# %%
# jannis
# !ls /kaggle/working/BOA-dataset-treatment/rtdl_revisiting_models/output/jannis/ft_transformer_attention/default/*/checkpoint.pt || echo "Aucun checkpoint trouvé"
# !ls /kaggle/working/BOA-dataset-treatment/rtdl_revisiting_models/output/jannis/sparse_ftt_plus_attention/default/*/checkpoint.pt || echo "Aucun checkpoint trouvé"
# Out:
# /kaggle/working/BOA-dataset-treatment/rtdl_revisiting_models/output/jannis/ft_transformer_attention/default/0/checkpoint.pt
# /kaggle/working/BOA-dataset-treatment/rtdl_revisiting_models/output/jannis/ft_transformer_attention/default/1/checkpoint.pt
# /kaggle/working/BOA-dataset-treatment/rtdl_revisiting_models/output/jannis/ft_transformer_attention/default/2/checkpoint.pt
# /kaggle/working/BOA-dataset-treatment/rtdl_revisiting_models/output/jannis/ft_transformer_attention/default/3/checkpoint.pt
# /kaggle/working/BOA-dataset-treatment/rtdl_revisiting_models/output/jannis/ft_transformer_attention/default/4/checkpoint.pt
# /kaggle/working/BOA-dataset-treatment/rtdl_revisiting_models/output/jannis/sparse_ftt_plus_attention/default/0/checkpoint.pt
# /kaggle/working/BOA-dataset-treatment/rtdl_revisiting_models/output/jannis/sparse_ftt_plus_attention/default/1/checkpoint.pt
# ...

# %%
# higgs_small
# !ls /kaggle/working/BOA-dataset-treatment/rtdl_revisiting_models/output/higgs_small/ft_transformer_attention/default/*/checkpoint.pt || echo "Aucun checkpoint trouvé"
# !ls /kaggle/working/BOA-dataset-treatment/rtdl_revisiting_models/output/higgs_small/sparse_ftt_plus_attention/default/*/checkpoint.pt || echo "Aucun checkpoint trouvé"
# Out:
# /kaggle/working/BOA-dataset-treatment/rtdl_revisiting_models/output/higgs_small/ft_transformer_attention/default/0/checkpoint.pt
# /kaggle/working/BOA-dataset-treatment/rtdl_revisiting_models/output/higgs_small/ft_transformer_attention/default/1/checkpoint.pt
# /kaggle/working/BOA-dataset-treatment/rtdl_revisiting_models/output/higgs_small/ft_transformer_attention/default/2/checkpoint.pt
# /kaggle/working/BOA-dataset-treatment/rtdl_revisiting_models/output/higgs_small/ft_transformer_attention/default/3/checkpoint.pt
# /kaggle/working/BOA-dataset-treatment/rtdl_revisiting_models/output/higgs_small/ft_transformer_attention/default/4/checkpoint.pt
# /kaggle/working/BOA-dataset-treatment/rtdl_revisiting_models/output/higgs_small/sparse_ftt_plus_attention/default/0/checkpoint.pt
# /kaggle/working/BOA-dataset-treatment/rtdl_revisiting_models/output/higgs_small/sparse_ftt_plus_attention/default/1/checkpoint.pt
# ...

# %% [markdown]
# # *Exécuter l'analyse*

# %%
# !python -m load_pretrained_attention_models
# Out:
# === Analyse d'attention avec modèles pré-entraînés ===
# Datasets: ['california_housing', 'helena', 'higgs_small', 'jannis']
# Modèles: ['ft_transformer_attention', 'sparse_ftt_plus_attention']
# Seeds: [0, 1, 2, 3, 4]
#
#
# ...
# Analyse: california_housing + ft_transformer_attention + seed=0
# ...
#
# === Analyse d'attention avec modèle pré-entraîné ===
# Dataset: california_housing, Modèle: ft_transformer_attention, Checkpoint: rtdl_revisiting_models/output/california_housing/ft_transformer_attention/default/0/checkpoint.pt
# Chargement du modèle pré-entraîné: rtdl_revisiting_models/output/california_housing/ft_transformer_attention/default/0/checkpoint.pt
# Utilisation de la config: rtdl_revisiting_models/output/california_housing/ft_transformer_attention/default/0.toml
# Using cached X: /kaggle/working/BOA-dataset-treatment/rtdl_revisiting_models/data/california_housing/build_X__quantile__mean__new__indices__0.pickle
# Modèle chargé avec succès. Nombre de paramètres: 893179
# ...

# %% [markdown]
# # *Download output*

# %%
import os
import shutil
from IPython.display import FileLink

# Définir le répertoire de travail
os.chdir('/kaggle/working')

# Définir le dossier à compresser et le nom du fichier ZIP
folder_to_zip = 'BOA-dataset-treatment'
output_zip = '/kaggle/working/BOA-dataset-treatment.zip'

# Vérifier que le dossier existe
if os.path.exists(folder_to_zip):
    # Créer l'archive ZIP
    shutil.make_archive('/kaggle/working/BOA-dataset-treatment', 'zip', folder_to_zip)
    
    # Vérifier que le fichier ZIP a été créé
    if os.path.exists(output_zip):
        # Générer un lien de téléchargement
        display(FileLink('BOA-dataset-treatment.zip'))
    else:
        print("Erreur : Le fichier ZIP n'a pas été créé.")
else:
    print(f"Erreur : Le dossier {folder_to_zip} n'existe pas.")
# Out:
# /kaggle/working/BOA-dataset-treatment.zip
