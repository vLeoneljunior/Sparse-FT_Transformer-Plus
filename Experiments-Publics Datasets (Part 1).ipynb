# %% [markdown]
# <a href="https://www.kaggle.com/code/loneljuniorvodounou/experiments-publics-datasets-part-1?scriptVersionId=258771175" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# !git clone https://github.com/vleonel-junior/Sparse-FT_Transformer-Plus.git

# %%
import sys
sys.path.append('/kaggle/working/Sparse-FT_Transformer-Plus')

# %%
# Vérifier le répertoire et les fichiers
# !pwd
# !ls -la

# %%
# Installer les dépendances
# !pip install "scikit-learn>=1.0,<2" -qqq > /dev/null 2>&1 && echo 'Installation de scikit-learn réussie'
# !pip install libzero==0.0.4 -qqq > /dev/null 2>&1 && echo 'Installation de libzero réussie'
# !pip install optuna -qqq > /dev/null 2>&1 && echo 'Installation de optuna réussie'
# !pip install sparsemax -qqq > /dev/null 2>&1 && echo 'Installation de sparsemax réussie'
# !pip install icecream -qqq > /dev/null 2>&1 && echo 'Installation de icecream réussie'
# !pip install pytomlpp -qqq > /dev/null 2>&1 && echo 'Installation de pytomlpp réussie'

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
import torch
print("CUDA disponible :", torch.cuda.is_available())
print("Indice du GPU :", torch.cuda.current_device())
print("Nom du GPU :", torch.cuda.get_device_name(torch.cuda.current_device()))

# %% [markdown]
# # Publics Datasets

# %% [markdown]
# <center><h2  style="color:white; background-color:#808b96; border-radius: 10px; padding:15px;"> Adult </h2></center>
#     Task type : Binclass

# %% [markdown]
# #### *Catboost*

# %%
# !PYTHONPATH=/kaggle/working/Sparse-FT_Transformer-Plus python /kaggle/working/Sparse-FT_Transformer-Plus/rtdl_revisiting_models/bin/tune.py -f /kaggle/working/Sparse-FT_Transformer-Plus/rtdl_revisiting_models/output/adult/catboost/tuning/0.toml

# %% [markdown]
# ### *ft-transformer*

# %%
# !PYTHONPATH=/kaggle/working/Sparse-FT_Transformer-Plus python /kaggle/working/Sparse-FT_Transformer-Plus/rtdl_revisiting_models/bin/tune.py -f /kaggle/working/Sparse-FT_Transformer-Plus/rtdl_revisiting_models/output/adult/ft_transformer/tuning/0.toml

# %% [markdown]
# ### *sparse ft-transformer +*

# %%
# !PYTHONPATH=/kaggle/working/Sparse-FT_Transformer-Plus python /kaggle/working/Sparse-FT_Transformer-Plus/rtdl_revisiting_models/bin/tune.py -f /kaggle/working/Sparse-FT_Transformer-Plus/rtdl_revisiting_models/output/adult/sparse_ftt_plus/tuning/0.toml

# %% [markdown]
# ### *mlp*

# %%
# !PYTHONPATH=/kaggle/working/Sparse-FT_Transformer-Plus python /kaggle/working/Sparse-FT_Transformer-Plus/rtdl_revisiting_models/bin/tune.py -f /kaggle/working/Sparse-FT_Transformer-Plus/rtdl_revisiting_models/output/adult/mlp/tuning/0.toml

# %% [markdown]
# ### *xgboost*

# %%
# !PYTHONPATH=/kaggle/working/Sparse-FT_Transformer-Plus python /kaggle/working/Sparse-FT_Transformer-Plus/rtdl_revisiting_models/bin/tune.py -f /kaggle/working/Sparse-FT_Transformer-Plus/rtdl_revisiting_models/output/adult/xgboost/tuning/0.toml

# %% [markdown]
# <center><h2  style="color:white; background-color:#808b96; border-radius: 10px; padding:15px;"> California Housing </h2></center>
#     Task type : Regression

# %% [markdown]
# ### *Catboost*

# %%
# !PYTHONPATH=/kaggle/working/Sparse-FT_Transformer-Plus python /kaggle/working/Sparse-FT_Transformer-Plus/rtdl_revisiting_models/bin/tune.py -f /kaggle/working/Sparse-FT_Transformer-Plus/rtdl_revisiting_models/output/california_housing/catboost/tuning/0.toml

# %% [markdown]
# ### *ft-transformer*

# %%
# !PYTHONPATH=/kaggle/working/Sparse-FT_Transformer-Plus python /kaggle/working/Sparse-FT_Transformer-Plus/rtdl_revisiting_models/bin/tune.py -f /kaggle/working/Sparse-FT_Transformer-Plus/rtdl_revisiting_models/output/california_housing/ft_transformer/tuning/0.toml

# %% [markdown]
# ### *sparse ft-transformer +*

# %%
# !PYTHONPATH=/kaggle/working/Sparse-FT_Transformer-Plus python /kaggle/working/Sparse-FT_Transformer-Plus/rtdl_revisiting_models/bin/tune.py -f /kaggle/working/Sparse-FT_Transformer-Plus/rtdl_revisiting_models/output/california_housing/sparse_ftt_plus/tuning/0.toml

# %% [markdown]
# ### *mlp*

# %%
# !PYTHONPATH=/kaggle/working/Sparse-FT_Transformer-Plus python /kaggle/working/Sparse-FT_Transformer-Plus/rtdl_revisiting_models/bin/tune.py -f /kaggle/working/Sparse-FT_Transformer-Plus/rtdl_revisiting_models/output/california_housing/mlp/tuning/0.toml

# %% [markdown]
# ### *xgboost*

# %%
# !PYTHONPATH=/kaggle/working/Sparse-FT_Transformer-Plus python /kaggle/working/Sparse-FT_Transformer-Plus/rtdl_revisiting_models/bin/tune.py -f /kaggle/working/Sparse-FT_Transformer-Plus/rtdl_revisiting_models/output/california_housing/xgboost/tuning/0.toml

# %% [markdown]
# ### *Compresser le dossier output en un fichier zip*

# %%
# !zip -r output.zip /kaggle/working/Sparse-FT_Transformer-Plus/rtdl_revisiting_models/output
