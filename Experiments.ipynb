# %%
# !git clone https://github.com/vleonel-junior/customer-churn-ft_transformer.git
# Out:
# Cloning into 'customer-churn-ft_transformer'...
# remote: Enumerating objects: 1217, done.
# remote: Counting objects: 100% (261/261), done.
# remote: Compressing objects: 100% (197/197), done.
# remote: Total 1217 (delta 125), reused 191 (delta 62), pack-reused 956 (from 1)
# Receiving objects: 100% (1217/1217), 6.01 MiB | 18.42 MiB/s, done.
# Resolving deltas: 100% (606/606), done.

# %%
import sys
sys.path.append('/kaggle/working/customer-churn-ft_transformer')

# %%
# Le bon chemin est directement :
import os
os.chdir('/kaggle/working/customer-churn-ft_transformer')

# Vérifier que vous êtes au bon endroit
# !pwd
# !ls -la

# Vérifier que les datasets sont là
# !ls -la data/
# Out:
# /kaggle/working/customer-churn-ft_transformer
# total 5916
# drwxr-xr-x 9 root root    4096 Jul 31 17:53 .
# drwxr-xr-x 3 root root    4096 Jul 31 17:53 ..
# drwxr-xr-x 3 root root    4096 Jul 31 17:53 data
# -rw-r--r-- 1 root root 5962887 Jul 31 17:53 Experiments.ipynb
# drwxr-xr-x 2 root root    4096 Jul 31 17:53 ftt_plus
# drwxr-xr-x 8 root root    4096 Jul 31 17:53 .git
# -rw-r--r-- 1 root root     686 Jul 31 17:53 .gitignore
# drwxr-xr-x 2 root root    4096 Jul 31 17:53 images
# -rw-r--r-- 1 root root   10781 Jul 31 17:53 interpretability_analyzer.py
# -rw-r--r-- 1 root root   10266 Jul 31 17:53 num_embedding_factory.py
# -rw-r--r-- 1 root root    6424 Jul 31 17:53 README.md
# drwxr-xr-x 5 root root    4096 Jul 31 17:53 rtdl_lib
# drwxr-xr-x 2 root root    4096 Jul 31 17:53 sparse_ftt_plus
# -rw-r--r-- 1 root root    6821 Jul 31 17:53 test_embeddings.py
# drwxr-xr-x 4 root root    4096 Jul 31 17:53 train
# -rw-r--r-- 1 root root    2333 Jul 31 17:53 utils.py
# -rw-r--r-- 1 root root    5340 Jul 31 17:53 visualisation.py
# total 1632
# drwxr-xr-x 3 root root   4096 Jul 31 17:53 .
# drwxr-xr-x 9 root root   4096 Jul 31 17:53 ..
# -rw-r--r-- 1 root root 674857 Jul 31 17:53 Churn_Modelling.csv
# -rw-r--r-- 1 root root   3727 Jul 31 17:53 process_bank_data.py
# -rw-r--r-- 1 root root   4224 Jul 31 17:53 process_telecom_data.py
# drwxr-xr-x 2 root root   4096 Jul 31 17:53 __pycache__
# -rw-r--r-- 1 root root 970457 Jul 31 17:53 Telco_Customer_Churn.csv
# -rw-r--r-- 1 root root      0 Jul 31 17:53 utils.py

# %%
# Installation silencieuse des packages pour rtdl_num_embeddings
# !pip install rtdl_num_embeddings -qqq > /dev/null 2>&1 && echo 'Installation de rtdl_num_embeddings réussie'
# !pip install "scikit-learn>=1.0,<2" -qqq > /dev/null 2>&1 && echo 'Installation de scikit-learn réussie'
# Out:
# Installation de rtdl_num_embeddings réussie
# Installation de scikit-learn réussie

# %%
# !pip install libzero==0.0.4 -qqq > /dev/null 2>&1 && echo 'Installation de libzero réussie'
# !pip install optuna -qqq > /dev/null 2>&1 && echo 'Installation de optuna réussie'
# !pip install sparsemax -qqq > /dev/null 2>&1 && echo 'Installation de sparsemax réussie'
# Out:
# Installation de libzero réussie
# Installation de optuna réussie
# Installation de sparsemax réussie

# %% [markdown]
# # Bank Dataset

# %% [markdown]
# ## FT-T training

# %%
import os

# Changer vers le répertoire racine
os.chdir('/kaggle/working/customer-churn-ft_transformer')

# Utiliser PYTHONPATH pour que train.py trouve les modules
# !PYTHONPATH=/kaggle/working/customer-churn-ft_transformer python train/Bank/train_ftt/train.py
# Out:
# Utilisation du device: cuda
# Seed: 0
# Données originales: 10000 lignes
# Après nettoyage: 10000 lignes (0 supprimées)
#
# Informations sur les features:
# Features numériques (6): ['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'EstimatedSalary']
# Variables catégorielles (4): ['Geography', 'Gender', 'HasCrCard', 'IsActiveMember']
# Cardinalités des variables catégorielles: [3, 2, 2, 2]
# Distribution des classes: [7963 2037]
# Tailles des ensembles:
# Train: 6800 | Val: 1200 | Test: 2000
# Configuration du modèle:
#   - Features numériques: 6
#   - Features catégorielles: 4 (cardinalités: [3, 2, 2, 2])
#   - Taille des tokens: 128
# Traceback (most recent call last):
#   File "/kaggle/working/customer-churn-ft_transformer/train/Bank/train_ftt/train.py", line 48, in <module>
#     model = FTTransformer.make_baseline(
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: FTTransformer.make_baseline() got an unexpected keyword argument 'attention_n_heads'

# %% [markdown]
# ## Interpretable FT-T+ Training

# %%
import os

# Changer vers le répertoire racine
os.chdir('/kaggle/working/customer-churn-ft_transformer')

# Utiliser PYTHONPATH pour que train.py trouve les modules
# !PYTHONPATH=/kaggle/working/customer-churn-ft_transformer python train/Bank/train_ftt_plus/train.py
# Out:
# Utilisation du device: cuda
# Seed: 0
# Données originales: 10000 lignes
# Après nettoyage: 10000 lignes (0 supprimées)
#
# Informations sur les features:
# Features numériques (6): ['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'EstimatedSalary']
# Variables catégorielles (4): ['Geography', 'Gender', 'HasCrCard', 'IsActiveMember']
# Cardinalités des variables catégorielles: [3, 2, 2, 2]
# Distribution des classes: [7963 2037]
# Tailles des ensembles:
# Train: 6800 | Val: 1200 | Test: 2000
# Configuration du modèle:
#   - Features numériques: 6
#   - Features catégorielles: 4 (cardinalités: [3, 2, 2, 2])
#   - Taille des tokens: 128
# Type d'embedding numérique: T
# /usr/local/lib/python3.11/dist-packages/rtdl_num_embeddings.py:499: UserWarning: Computing tree-based bins involves the conversion of the input PyTorch tensors to NumPy arrays. The provided PyTorch tensors are not located on CPU, so the conversion has some overhead.
#   warnings.warn(
# Nombre de paramètres: 504,065
#
# === Début de l'entraînement ===
# Epoch 000 | Training loss: 0.5426
# Epoch 000 | Validation loss: 0.4585
# Epoch 000 completed in 15.46s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.4585)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.749, AUC-PR: 0.4438, Accuracy: 0.7965, B_ACC : 0.5, MCC: 0.0, Sensitivity/Recall: 0.0, Specificity: 1.0, Precision: 0.0, F1-score: 0.0, CK-score 0.0
# Test Performance:
#   ROC-AUC: 0.7490 | PR-AUC: 0.4438 | Accuracy: 0.7965
#   F1: 0.0000 | MCC: 0.0000 | Balanced Acc: 0.5000
# ------------------------------------------------------------
# Epoch 001 | Training loss: 0.4524
# Epoch 001 | Validation loss: 0.4233
# Epoch 001 completed in 15.14s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.4233)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.7724, AUC-PR: 0.5071, Accuracy: 0.8065, B_ACC : 0.5273, MCC: 0.1942, Sensitivity/Recall: 0.0565, Specificity: 0.9981, Precision: 0.8846, F1-score: 0.1062, CK-score 0.0838
# Test Performance:
#   ROC-AUC: 0.7724 | PR-AUC: 0.5071 | Accuracy: 0.8065
#   F1: 0.1062 | MCC: 0.1942 | Balanced Acc: 0.5273
# ------------------------------------------------------------
# Epoch 002 | Training loss: 0.4247
# Epoch 002 | Validation loss: 0.4075
# Epoch 002 completed in 15.05s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.4075)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.7858, AUC-PR: 0.5412, Accuracy: 0.825, B_ACC : 0.6039, MCC: 0.338, Sensitivity/Recall: 0.231, Specificity: 0.9768, Precision: 0.7176, F1-score: 0.3495, CK-score 0.2779
# Test Performance:
#   ROC-AUC: 0.7858 | PR-AUC: 0.5412 | Accuracy: 0.8250
#   F1: 0.3495 | MCC: 0.3380 | Balanced Acc: 0.6039
# ------------------------------------------------------------
# Epoch 003 | Training loss: 0.4101
# Epoch 003 | Validation loss: 0.3986
# Epoch 003 completed in 14.87s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.3986)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.7975, AUC-PR: 0.5625, Accuracy: 0.8315, B_ACC : 0.6299, MCC: 0.3791, Sensitivity/Recall: 0.2899, Specificity: 0.9699, Precision: 0.7108, F1-score: 0.4118, CK-score 0.3333
# Test Performance:
#   ROC-AUC: 0.7975 | PR-AUC: 0.5625 | Accuracy: 0.8315
#   F1: 0.4118 | MCC: 0.3791 | Balanced Acc: 0.6299
# ------------------------------------------------------------
# Epoch 004 | Training loss: 0.4005
# Epoch 004 | Validation loss: 0.3922
# Epoch 004 completed in 15.08s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.3922)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.809, AUC-PR: 0.5789, Accuracy: 0.836, B_ACC : 0.6419, MCC: 0.4022, Sensitivity/Recall: 0.3145, Specificity: 0.9692, Precision: 0.7232, F1-score: 0.4384, CK-score 0.3593
# Test Performance:
#   ROC-AUC: 0.8090 | PR-AUC: 0.5789 | Accuracy: 0.8360
#   F1: 0.4384 | MCC: 0.4022 | Balanced Acc: 0.6419
# ------------------------------------------------------------
# Epoch 005 | Training loss: 0.3928
# Epoch 005 | Validation loss: 0.3849
# Epoch 005 completed in 14.89s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.3849)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8194, AUC-PR: 0.5928, Accuracy: 0.8375, B_ACC : 0.651, MCC: 0.4128, Sensitivity/Recall: 0.3366, Specificity: 0.9655, Precision: 0.7135, F1-score: 0.4574, CK-score 0.376
# Test Performance:
#   ROC-AUC: 0.8194 | PR-AUC: 0.5928 | Accuracy: 0.8375
#   F1: 0.4574 | MCC: 0.4128 | Balanced Acc: 0.6510
# ------------------------------------------------------------
# Epoch 006 | Training loss: 0.3874
# Epoch 006 | Validation loss: 0.3802
# Epoch 006 completed in 14.86s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.3802)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8286, AUC-PR: 0.6086, Accuracy: 0.839, B_ACC : 0.6538, MCC: 0.4194, Sensitivity/Recall: 0.3415, Specificity: 0.9661, Precision: 0.7202, F1-score: 0.4633, CK-score 0.3825
# Test Performance:
#   ROC-AUC: 0.8286 | PR-AUC: 0.6086 | Accuracy: 0.8390
#   F1: 0.4633 | MCC: 0.4194 | Balanced Acc: 0.6538
# ------------------------------------------------------------
# Epoch 007 | Training loss: 0.3796
# Epoch 007 | Validation loss: 0.3750
# Epoch 007 completed in 15.01s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.3750)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.835, AUC-PR: 0.6237, Accuracy: 0.842, B_ACC : 0.6603, MCC: 0.4331, Sensitivity/Recall: 0.3538, Specificity: 0.9667, Precision: 0.731, F1-score: 0.4768, CK-score 0.3967
# Test Performance:
#   ROC-AUC: 0.8350 | PR-AUC: 0.6237 | Accuracy: 0.8420
#   F1: 0.4768 | MCC: 0.4331 | Balanced Acc: 0.6603
# ------------------------------------------------------------
# Epoch 008 | Training loss: 0.3736
# Epoch 008 | Validation loss: 0.3689
# Epoch 008 completed in 15.13s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.3689)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8407, AUC-PR: 0.6403, Accuracy: 0.8475, B_ACC : 0.671, MCC: 0.457, Sensitivity/Recall: 0.3735, Specificity: 0.9686, Precision: 0.7525, F1-score: 0.4992, CK-score 0.421
# Test Performance:
#   ROC-AUC: 0.8407 | PR-AUC: 0.6403 | Accuracy: 0.8475
#   F1: 0.4992 | MCC: 0.4570 | Balanced Acc: 0.6710
# ------------------------------------------------------------
# Epoch 009 | Training loss: 0.3680
# Epoch 009 | Validation loss: 0.3658
# Epoch 009 completed in 15.14s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.3658)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8446, AUC-PR: 0.6531, Accuracy: 0.851, B_ACC : 0.6769, MCC: 0.4717, Sensitivity/Recall: 0.3833, Specificity: 0.9705, Precision: 0.7685, F1-score: 0.5115, CK-score 0.4349
# Test Performance:
#   ROC-AUC: 0.8446 | PR-AUC: 0.6531 | Accuracy: 0.8510
#   F1: 0.5115 | MCC: 0.4717 | Balanced Acc: 0.6769
# ------------------------------------------------------------
# Epoch 010 | Training loss: 0.3624
# Epoch 010 | Validation loss: 0.3624
# Epoch 010 completed in 15.00s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.3624)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8463, AUC-PR: 0.6642, Accuracy: 0.8555, B_ACC : 0.6843, MCC: 0.4903, Sensitivity/Recall: 0.3956, Specificity: 0.973, Precision: 0.7892, F1-score: 0.527, CK-score 0.4526
# Test Performance:
#   ROC-AUC: 0.8463 | PR-AUC: 0.6642 | Accuracy: 0.8555
#   F1: 0.5270 | MCC: 0.4903 | Balanced Acc: 0.6843
# ------------------------------------------------------------
# Epoch 011 | Training loss: 0.3572
# Epoch 011 | Validation loss: 0.3615
# Epoch 011 completed in 14.97s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.3615)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8472, AUC-PR: 0.67, Accuracy: 0.857, B_ACC : 0.6889, MCC: 0.4972, Sensitivity/Recall: 0.4054, Specificity: 0.9724, Precision: 0.7895, F1-score: 0.5357, CK-score 0.4613
# Test Performance:
#   ROC-AUC: 0.8472 | PR-AUC: 0.6700 | Accuracy: 0.8570
#   F1: 0.5357 | MCC: 0.4972 | Balanced Acc: 0.6889
# ------------------------------------------------------------
# Epoch 012 | Training loss: 0.3576
# Epoch 012 | Validation loss: 0.3596
# Epoch 012 completed in 14.92s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.3596)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8477, AUC-PR: 0.6725, Accuracy: 0.8565, B_ACC : 0.6922, MCC: 0.4967, Sensitivity/Recall: 0.4152, Specificity: 0.9692, Precision: 0.7752, F1-score: 0.5408, CK-score 0.4648
# Test Performance:
#   ROC-AUC: 0.8477 | PR-AUC: 0.6725 | Accuracy: 0.8565
#   F1: 0.5408 | MCC: 0.4967 | Balanced Acc: 0.6922
# ------------------------------------------------------------
# Epoch 013 | Training loss: 0.3570
# Epoch 013 | Validation loss: 0.3595
# Epoch 013 completed in 14.88s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.3595)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8482, AUC-PR: 0.6754, Accuracy: 0.857, B_ACC : 0.6926, MCC: 0.4985, Sensitivity/Recall: 0.4152, Specificity: 0.9699, Precision: 0.7788, F1-score: 0.5416, CK-score 0.4661
# Test Performance:
#   ROC-AUC: 0.8482 | PR-AUC: 0.6754 | Accuracy: 0.8570
#   F1: 0.5416 | MCC: 0.4985 | Balanced Acc: 0.6926
# ------------------------------------------------------------
# Epoch 014 | Training loss: 0.3530
# Epoch 014 | Validation loss: 0.3592
# Epoch 014 completed in 15.08s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.3592)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8492, AUC-PR: 0.6767, Accuracy: 0.858, B_ACC : 0.6932, MCC: 0.5022, Sensitivity/Recall: 0.4152, Specificity: 0.9711, Precision: 0.786, F1-score: 0.5434, CK-score 0.4687
# Test Performance:
#   ROC-AUC: 0.8492 | PR-AUC: 0.6767 | Accuracy: 0.8580
#   F1: 0.5434 | MCC: 0.5022 | Balanced Acc: 0.6932
# ------------------------------------------------------------
# Epoch 015 | Training loss: 0.3505
# Epoch 015 | Validation loss: 0.3591
# Epoch 015 completed in 14.81s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.3591)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8489, AUC-PR: 0.6765, Accuracy: 0.8565, B_ACC : 0.6941, MCC: 0.4974, Sensitivity/Recall: 0.4201, Specificity: 0.968, Precision: 0.7703, F1-score: 0.5437, CK-score 0.4672
# Test Performance:
#   ROC-AUC: 0.8489 | PR-AUC: 0.6765 | Accuracy: 0.8565
#   F1: 0.5437 | MCC: 0.4974 | Balanced Acc: 0.6941
# ------------------------------------------------------------
# Epoch 016 | Training loss: 0.3484
# Epoch 016 | Validation loss: 0.3586
# Epoch 016 completed in 15.19s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.3586)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8503, AUC-PR: 0.6777, Accuracy: 0.8555, B_ACC : 0.6944, MCC: 0.4943, Sensitivity/Recall: 0.4226, Specificity: 0.9661, Precision: 0.7611, F1-score: 0.5434, CK-score 0.4658
# Test Performance:
#   ROC-AUC: 0.8503 | PR-AUC: 0.6777 | Accuracy: 0.8555
#   F1: 0.5434 | MCC: 0.4943 | Balanced Acc: 0.6944
# ------------------------------------------------------------
# Epoch 017 | Training loss: 0.3466
# Epoch 017 | Validation loss: 0.3592
# Epoch 017 completed in 15.12s
# ------------------------------------------------------------
# Epoch 018 | Training loss: 0.3487
# Epoch 018 | Validation loss: 0.3576
# Epoch 018 completed in 15.05s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.3576)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8507, AUC-PR: 0.6784, Accuracy: 0.8565, B_ACC : 0.6932, MCC: 0.4971, Sensitivity/Recall: 0.4177, Specificity: 0.9686, Precision: 0.7727, F1-score: 0.5423, CK-score 0.466
# Test Performance:
#   ROC-AUC: 0.8507 | PR-AUC: 0.6784 | Accuracy: 0.8565
#   F1: 0.5423 | MCC: 0.4971 | Balanced Acc: 0.6932
# ------------------------------------------------------------
# Epoch 019 | Training loss: 0.3471
# Epoch 019 | Validation loss: 0.3569
# Epoch 019 completed in 14.78s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.3569)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8505, AUC-PR: 0.6783, Accuracy: 0.855, B_ACC : 0.6913, MCC: 0.4913, Sensitivity/Recall: 0.4152, Specificity: 0.9674, Precision: 0.7647, F1-score: 0.5382, CK-score 0.461
# Test Performance:
#   ROC-AUC: 0.8505 | PR-AUC: 0.6783 | Accuracy: 0.8550
#   F1: 0.5382 | MCC: 0.4913 | Balanced Acc: 0.6913
# ------------------------------------------------------------
# Epoch 020 | Training loss: 0.3447
# Epoch 020 | Validation loss: 0.3575
# Epoch 020 completed in 15.11s
# ------------------------------------------------------------
# Epoch 021 | Training loss: 0.3426
# Epoch 021 | Validation loss: 0.3567
# Epoch 021 completed in 15.05s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.3567)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8523, AUC-PR: 0.6802, Accuracy: 0.854, B_ACC : 0.6925, MCC: 0.4886, Sensitivity/Recall: 0.4201, Specificity: 0.9648, Precision: 0.7533, F1-score: 0.5394, CK-score 0.4609
# Test Performance:
#   ROC-AUC: 0.8523 | PR-AUC: 0.6802 | Accuracy: 0.8540
#   F1: 0.5394 | MCC: 0.4886 | Balanced Acc: 0.6925
# ------------------------------------------------------------
# Epoch 022 | Training loss: 0.3440
# Epoch 022 | Validation loss: 0.3563
# Epoch 022 completed in 15.03s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.3563)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8523, AUC-PR: 0.6804, Accuracy: 0.856, B_ACC : 0.6938, MCC: 0.4957, Sensitivity/Recall: 0.4201, Specificity: 0.9674, Precision: 0.7668, F1-score: 0.5428, CK-score 0.4659
# Test Performance:
#   ROC-AUC: 0.8523 | PR-AUC: 0.6804 | Accuracy: 0.8560
#   F1: 0.5428 | MCC: 0.4957 | Balanced Acc: 0.6938
# ------------------------------------------------------------
# Epoch 023 | Training loss: 0.3428
# Epoch 023 | Validation loss: 0.3580
# Epoch 023 completed in 15.03s
# ------------------------------------------------------------
# Epoch 024 | Training loss: 0.3406
# Epoch 024 | Validation loss: 0.3568
# Epoch 024 completed in 15.10s
# ------------------------------------------------------------
# Epoch 025 | Training loss: 0.3406
# Epoch 025 | Validation loss: 0.3571
# Epoch 025 completed in 14.98s
# ------------------------------------------------------------
# Epoch 026 | Training loss: 0.3421
# Epoch 026 | Validation loss: 0.3557
# Epoch 026 completed in 15.08s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.3557)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8531, AUC-PR: 0.6808, Accuracy: 0.8575, B_ACC : 0.6984, MCC: 0.5025, Sensitivity/Recall: 0.43, Specificity: 0.9667, Precision: 0.7675, F1-score: 0.5512, CK-score 0.4744
# Test Performance:
#   ROC-AUC: 0.8531 | PR-AUC: 0.6808 | Accuracy: 0.8575
#   F1: 0.5512 | MCC: 0.5025 | Balanced Acc: 0.6984
# ------------------------------------------------------------
# Epoch 027 | Training loss: 0.3388
# Epoch 027 | Validation loss: 0.3558
# Epoch 027 completed in 14.85s
# ------------------------------------------------------------
# Epoch 028 | Training loss: 0.3362
# Epoch 028 | Validation loss: 0.3570
# Epoch 028 completed in 14.98s
# ------------------------------------------------------------
# Epoch 029 | Training loss: 0.3385
# Epoch 029 | Validation loss: 0.3539
# Epoch 029 completed in 14.96s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.3539)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.853, AUC-PR: 0.6805, Accuracy: 0.857, B_ACC : 0.6962, MCC: 0.5, Sensitivity/Recall: 0.4251, Specificity: 0.9674, Precision: 0.7689, F1-score: 0.5475, CK-score 0.4708
# Test Performance:
#   ROC-AUC: 0.8530 | PR-AUC: 0.6805 | Accuracy: 0.8570
#   F1: 0.5475 | MCC: 0.5000 | Balanced Acc: 0.6962
# ------------------------------------------------------------
# Epoch 030 | Training loss: 0.3387
# Epoch 030 | Validation loss: 0.3529
# Epoch 030 completed in 14.89s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.3529)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8527, AUC-PR: 0.6811, Accuracy: 0.8565, B_ACC : 0.6968, MCC: 0.4986, Sensitivity/Recall: 0.4275, Specificity: 0.9661, Precision: 0.7632, F1-score: 0.548, CK-score 0.4707
# Test Performance:
#   ROC-AUC: 0.8527 | PR-AUC: 0.6811 | Accuracy: 0.8565
#   F1: 0.5480 | MCC: 0.4986 | Balanced Acc: 0.6968
# ------------------------------------------------------------
# Epoch 031 | Training loss: 0.3410
# Epoch 031 | Validation loss: 0.3529
# Epoch 031 completed in 14.77s
# ------------------------------------------------------------
# Epoch 032 | Training loss: 0.3387
# Epoch 032 | Validation loss: 0.3545
# Epoch 032 completed in 14.99s
# ------------------------------------------------------------
# Epoch 033 | Training loss: 0.3368
# Epoch 033 | Validation loss: 0.3534
# Epoch 033 completed in 14.88s
# ------------------------------------------------------------
# Epoch 034 | Training loss: 0.3359
# Epoch 034 | Validation loss: 0.3546
# Epoch 034 completed in 14.87s
# ------------------------------------------------------------
# Epoch 035 | Training loss: 0.3354
# Epoch 035 | Validation loss: 0.3551
# Epoch 035 completed in 14.88s
# ------------------------------------------------------------
# Epoch 036 | Training loss: 0.3352
# Epoch 036 | Validation loss: 0.3541
# Epoch 036 completed in 14.79s
# ------------------------------------------------------------
# Epoch 037 | Training loss: 0.3347
# Epoch 037 | Validation loss: 0.3544
# Epoch 037 completed in 14.71s
# ------------------------------------------------------------
# Epoch 038 | Training loss: 0.3314
# Epoch 038 | Validation loss: 0.3539
# Epoch 038 completed in 14.71s
# ------------------------------------------------------------
# Epoch 039 | Training loss: 0.3339
# Epoch 039 | Validation loss: 0.3543
# Epoch 039 completed in 14.68s
# ------------------------------------------------------------
# Epoch 040 | Training loss: 0.3363
# Epoch 040 | Validation loss: 0.3531
# Epoch 040 completed in 14.63s
# ------------------------------------------------------------
# Epoch 041 | Training loss: 0.3357
# Epoch 041 | Validation loss: 0.3530
# Epoch 041 completed in 14.33s
# ------------------------------------------------------------
# Epoch 042 | Training loss: 0.3346
# Epoch 042 | Validation loss: 0.3524
# Epoch 042 completed in 14.37s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.3524)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8549, AUC-PR: 0.6829, Accuracy: 0.857, B_ACC : 0.699, MCC: 0.5012, Sensitivity/Recall: 0.4324, Specificity: 0.9655, Precision: 0.7619, F1-score: 0.5517, CK-score 0.4742
# Test Performance:
#   ROC-AUC: 0.8549 | PR-AUC: 0.6829 | Accuracy: 0.8570
#   F1: 0.5517 | MCC: 0.5012 | Balanced Acc: 0.6990
# ------------------------------------------------------------
# Epoch 043 | Training loss: 0.3338
# Epoch 043 | Validation loss: 0.3514
# Epoch 043 completed in 14.46s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.3514)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8545, AUC-PR: 0.6827, Accuracy: 0.8565, B_ACC : 0.6968, MCC: 0.4986, Sensitivity/Recall: 0.4275, Specificity: 0.9661, Precision: 0.7632, F1-score: 0.548, CK-score 0.4707
# Test Performance:
#   ROC-AUC: 0.8545 | PR-AUC: 0.6827 | Accuracy: 0.8565
#   F1: 0.5480 | MCC: 0.4986 | Balanced Acc: 0.6968
# ------------------------------------------------------------
# Epoch 044 | Training loss: 0.3327
# Epoch 044 | Validation loss: 0.3517
# Epoch 044 completed in 14.29s
# ------------------------------------------------------------
# Epoch 045 | Training loss: 0.3323
# Epoch 045 | Validation loss: 0.3516
# Epoch 045 completed in 14.26s
# ------------------------------------------------------------
# Epoch 046 | Training loss: 0.3303
# Epoch 046 | Validation loss: 0.3530
# Epoch 046 completed in 14.11s
# ------------------------------------------------------------
# Epoch 047 | Training loss: 0.3299
# Epoch 047 | Validation loss: 0.3520
# Epoch 047 completed in 13.98s
# ------------------------------------------------------------
# Epoch 048 | Training loss: 0.3331
# Epoch 048 | Validation loss: 0.3536
# Epoch 048 completed in 14.21s
# ------------------------------------------------------------
# Epoch 049 | Training loss: 0.3318
# Epoch 049 | Validation loss: 0.3534
# Epoch 049 completed in 14.20s
# ------------------------------------------------------------
# Epoch 050 | Training loss: 0.3304
# Epoch 050 | Validation loss: 0.3523
# Epoch 050 completed in 14.26s
# ------------------------------------------------------------
# Epoch 051 | Training loss: 0.3321
# Epoch 051 | Validation loss: 0.3535
# Epoch 051 completed in 14.19s
# ------------------------------------------------------------
# Epoch 052 | Training loss: 0.3332
# Epoch 052 | Validation loss: 0.3533
# Epoch 052 completed in 14.04s
# ------------------------------------------------------------
# Epoch 053 | Training loss: 0.3312
# Epoch 053 | Validation loss: 0.3535
# Epoch 053 completed in 13.67s
# ------------------------------------------------------------
# Epoch 054 | Training loss: 0.3329
# Epoch 054 | Validation loss: 0.3521
# Epoch 054 completed in 13.86s
# ------------------------------------------------------------
# Epoch 055 | Training loss: 0.3277
# Epoch 055 | Validation loss: 0.3530
# Epoch 055 completed in 13.79s
# ------------------------------------------------------------
# Epoch 056 | Training loss: 0.3312
# Epoch 056 | Validation loss: 0.3515
# Epoch 056 completed in 13.75s
# ------------------------------------------------------------
# Epoch 057 | Training loss: 0.3309
# Epoch 057 | Validation loss: 0.3509
# Epoch 057 completed in 14.03s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.3509)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8542, AUC-PR: 0.6824, Accuracy: 0.8585, B_ACC : 0.6944, MCC: 0.5043, Sensitivity/Recall: 0.4177, Specificity: 0.9711, Precision: 0.787, F1-score: 0.5457, CK-score 0.4711
# Test Performance:
#   ROC-AUC: 0.8542 | PR-AUC: 0.6824 | Accuracy: 0.8585
#   F1: 0.5457 | MCC: 0.5043 | Balanced Acc: 0.6944
# ------------------------------------------------------------
# Epoch 058 | Training loss: 0.3302
# Epoch 058 | Validation loss: 0.3519
# Epoch 058 completed in 14.10s
# ------------------------------------------------------------
# Epoch 059 | Training loss: 0.3290
# Epoch 059 | Validation loss: 0.3520
# Epoch 059 completed in 13.77s
# ------------------------------------------------------------
# Epoch 060 | Training loss: 0.3288
# Epoch 060 | Validation loss: 0.3518
# Epoch 060 completed in 14.07s
# ------------------------------------------------------------
# Epoch 061 | Training loss: 0.3288
# Epoch 061 | Validation loss: 0.3535
# Epoch 061 completed in 13.85s
# ------------------------------------------------------------
# Epoch 062 | Training loss: 0.3294
# Epoch 062 | Validation loss: 0.3525
# Epoch 062 completed in 13.97s
# ------------------------------------------------------------
# Epoch 063 | Training loss: 0.3255
# Epoch 063 | Validation loss: 0.3515
# Epoch 063 completed in 14.03s
# ------------------------------------------------------------
# Epoch 064 | Training loss: 0.3290
# Epoch 064 | Validation loss: 0.3518
# Epoch 064 completed in 13.90s
# ------------------------------------------------------------
# Epoch 065 | Training loss: 0.3302
# Epoch 065 | Validation loss: 0.3520
# Epoch 065 completed in 14.01s
# ------------------------------------------------------------
# Epoch 066 | Training loss: 0.3269
# Epoch 066 | Validation loss: 0.3508
# Epoch 066 completed in 13.95s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.3508)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8546, AUC-PR: 0.6819, Accuracy: 0.8585, B_ACC : 0.6972, MCC: 0.5053, Sensitivity/Recall: 0.4251, Specificity: 0.9692, Precision: 0.7793, F1-score: 0.5501, CK-score 0.4746
# Test Performance:
#   ROC-AUC: 0.8546 | PR-AUC: 0.6819 | Accuracy: 0.8585
#   F1: 0.5501 | MCC: 0.5053 | Balanced Acc: 0.6972
# ------------------------------------------------------------
# Epoch 067 | Training loss: 0.3242
# Epoch 067 | Validation loss: 0.3521
# Epoch 067 completed in 13.81s
# ------------------------------------------------------------
# Epoch 068 | Training loss: 0.3279
# Epoch 068 | Validation loss: 0.3510
# Epoch 068 completed in 13.77s
# ------------------------------------------------------------
# Epoch 069 | Training loss: 0.3242
# Epoch 069 | Validation loss: 0.3523
# Epoch 069 completed in 13.91s
# ------------------------------------------------------------
# Epoch 070 | Training loss: 0.3276
# Epoch 070 | Validation loss: 0.3521
# Epoch 070 completed in 13.99s
# ------------------------------------------------------------
# Epoch 071 | Training loss: 0.3270
# Epoch 071 | Validation loss: 0.3514
# Epoch 071 completed in 13.66s
# ------------------------------------------------------------
# Epoch 072 | Training loss: 0.3251
# Epoch 072 | Validation loss: 0.3507
# Epoch 072 completed in 13.53s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.3507)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8552, AUC-PR: 0.6829, Accuracy: 0.8555, B_ACC : 0.6971, MCC: 0.4956, Sensitivity/Recall: 0.43, Specificity: 0.9642, Precision: 0.7543, F1-score: 0.5477, CK-score 0.4693
# Test Performance:
#   ROC-AUC: 0.8552 | PR-AUC: 0.6829 | Accuracy: 0.8555
#   F1: 0.5477 | MCC: 0.4956 | Balanced Acc: 0.6971
# ------------------------------------------------------------
# Epoch 073 | Training loss: 0.3237
# Epoch 073 | Validation loss: 0.3505
# Epoch 073 completed in 13.75s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.3505)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8547, AUC-PR: 0.6822, Accuracy: 0.8555, B_ACC : 0.6971, MCC: 0.4956, Sensitivity/Recall: 0.43, Specificity: 0.9642, Precision: 0.7543, F1-score: 0.5477, CK-score 0.4693
# Test Performance:
#   ROC-AUC: 0.8547 | PR-AUC: 0.6822 | Accuracy: 0.8555
#   F1: 0.5477 | MCC: 0.4956 | Balanced Acc: 0.6971
# ------------------------------------------------------------
# Epoch 074 | Training loss: 0.3257
# Epoch 074 | Validation loss: 0.3499
# Epoch 074 completed in 13.72s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.3499)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8547, AUC-PR: 0.6821, Accuracy: 0.855, B_ACC : 0.6959, MCC: 0.4934, Sensitivity/Recall: 0.4275, Specificity: 0.9642, Precision: 0.7532, F1-score: 0.5454, CK-score 0.4669
# Test Performance:
#   ROC-AUC: 0.8547 | PR-AUC: 0.6821 | Accuracy: 0.8550
#   F1: 0.5454 | MCC: 0.4934 | Balanced Acc: 0.6959
# ------------------------------------------------------------
# Epoch 075 | Training loss: 0.3251
# Epoch 075 | Validation loss: 0.3515
# Epoch 075 completed in 13.71s
# ------------------------------------------------------------
# Epoch 076 | Training loss: 0.3237
# Epoch 076 | Validation loss: 0.3526
# Epoch 076 completed in 13.55s
# ------------------------------------------------------------
# Epoch 077 | Training loss: 0.3259
# Epoch 077 | Validation loss: 0.3514
# Epoch 077 completed in 13.76s
# ------------------------------------------------------------
# Epoch 078 | Training loss: 0.3276
# Epoch 078 | Validation loss: 0.3501
# Epoch 078 completed in 13.82s
# ------------------------------------------------------------
# Epoch 079 | Training loss: 0.3235
# Epoch 079 | Validation loss: 0.3530
# Epoch 079 completed in 13.96s
# ------------------------------------------------------------
# Epoch 080 | Training loss: 0.3263
# Epoch 080 | Validation loss: 0.3515
# Epoch 080 completed in 14.06s
# ------------------------------------------------------------
# Epoch 081 | Training loss: 0.3245
# Epoch 081 | Validation loss: 0.3511
# Epoch 081 completed in 14.17s
# ------------------------------------------------------------
# Epoch 082 | Training loss: 0.3236
# Epoch 082 | Validation loss: 0.3506
# Epoch 082 completed in 14.19s
# ------------------------------------------------------------
# Epoch 083 | Training loss: 0.3226
# Epoch 083 | Validation loss: 0.3515
# Epoch 083 completed in 14.13s
# ------------------------------------------------------------
# Epoch 084 | Training loss: 0.3236
# Epoch 084 | Validation loss: 0.3511
# Epoch 084 completed in 14.21s
# ------------------------------------------------------------
# Epoch 085 | Training loss: 0.3221
# Epoch 085 | Validation loss: 0.3518
# Epoch 085 completed in 14.13s
# ------------------------------------------------------------
# Epoch 086 | Training loss: 0.3220
# Epoch 086 | Validation loss: 0.3509
# Epoch 086 completed in 14.44s
# ------------------------------------------------------------
# Epoch 087 | Training loss: 0.3223
# Epoch 087 | Validation loss: 0.3512
# Epoch 087 completed in 14.33s
# ------------------------------------------------------------
# Epoch 088 | Training loss: 0.3229
# Epoch 088 | Validation loss: 0.3522
# Epoch 088 completed in 14.46s
# ------------------------------------------------------------
# Epoch 089 | Training loss: 0.3233
# Epoch 089 | Validation loss: 0.3527
# Epoch 089 completed in 14.47s
# ------------------------------------------------------------
# Epoch 090 | Training loss: 0.3213
# Epoch 090 | Validation loss: 0.3505
# Epoch 090 completed in 14.38s
# ------------------------------------------------------------
# Epoch 091 | Training loss: 0.3205
# Epoch 091 | Validation loss: 0.3516
# Epoch 091 completed in 14.00s
# ------------------------------------------------------------
# Epoch 092 | Training loss: 0.3196
# Epoch 092 | Validation loss: 0.3521
# Epoch 092 completed in 14.18s
# ------------------------------------------------------------
# Epoch 093 | Training loss: 0.3207
# Epoch 093 | Validation loss: 0.3539
# Epoch 093 completed in 14.27s
# ------------------------------------------------------------
# Epoch 094 | Training loss: 0.3206
# Epoch 094 | Validation loss: 0.3542
# Epoch 094 completed in 14.47s
# ------------------------------------------------------------
# Epoch 095 | Training loss: 0.3243
# Epoch 095 | Validation loss: 0.3515
# Epoch 095 completed in 14.43s
# ------------------------------------------------------------
# Epoch 096 | Training loss: 0.3205
# Epoch 096 | Validation loss: 0.3545
# Epoch 096 completed in 14.57s
# ------------------------------------------------------------
# Epoch 097 | Training loss: 0.3194
# Epoch 097 | Validation loss: 0.3532
# Epoch 097 completed in 14.51s
# ------------------------------------------------------------
# Epoch 098 | Training loss: 0.3179
# Epoch 098 | Validation loss: 0.3513
# Epoch 098 completed in 14.42s
# ------------------------------------------------------------
# Epoch 099 | Training loss: 0.3214
# Epoch 099 | Validation loss: 0.3527
# Epoch 099 completed in 14.60s
# ------------------------------------------------------------
# Epoch 100 | Training loss: 0.3195
# Epoch 100 | Validation loss: 0.3532
# Epoch 100 completed in 14.47s
# ------------------------------------------------------------
# Epoch 101 | Training loss: 0.3189
# Epoch 101 | Validation loss: 0.3531
# Epoch 101 completed in 14.50s
# ------------------------------------------------------------
# Epoch 102 | Training loss: 0.3204
# Epoch 102 | Validation loss: 0.3527
# Epoch 102 completed in 14.52s
# ------------------------------------------------------------
# Epoch 103 | Training loss: 0.3171
# Epoch 103 | Validation loss: 0.3517
# Epoch 103 completed in 14.66s
#
# Early stopping à l'époque 103 (patience: 29)
#
# Meilleur modèle chargé (époque 74, val_loss: 0.3499)
#
# === Évaluation finale ===
# Performance sur l'ensemble de validation:
# Performance for test_dataset
# AUC-ROC: 0.8637, AUC-PR: 0.6699, Accuracy: 0.8517, B_ACC : 0.6902, MCC: 0.4799, Sensitivity/Recall: 0.418, Specificity: 0.9623, Precision: 0.7391, F1-score: 0.534, CK-score 0.4538
# Val Performance:
#   ROC-AUC: 0.8637 | PR-AUC: 0.6699 | Accuracy: 0.8517
#   F1: 0.5340 | MCC: 0.4799 | Balanced Acc: 0.6902
#
# Performance sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8528, AUC-PR: 0.6779, Accuracy: 0.855, B_ACC : 0.6959, MCC: 0.4934, Sensitivity/Recall: 0.4275, Specificity: 0.9642, Precision: 0.7532, F1-score: 0.5454, CK-score 0.4669
# Test Performance:
#   ROC-AUC: 0.8528 | PR-AUC: 0.6779 | Accuracy: 0.8550
#   F1: 0.5454 | MCC: 0.4934 | Balanced Acc: 0.6959
#
# === Analyse d'interprétabilité ===
#
# Top 10 features importantes:
#    1. CreditScore         : 0.1091
#    2. Gender              : 0.1026
#    3. Tenure              : 0.1026
#    4. Balance             : 0.1012
#    5. Age                 : 0.1011
#    6. Geography           : 0.1006
#    7. HasCrCard           : 0.0988
#    8. NumOfProducts       : 0.0955
#    9. EstimatedSalary     : 0.0944
#   10. IsActiveMember      : 0.0940
#
# Génération des visualisations...
# Graphique d'importance sauvegardé: results/results_bank/ftt_plus/seed_0/heatmaps/interpretable_ftt_plus_importance_seed_0.png
# Avertissement: Impossible de générer la heatmap d'attention pour interpretable_ftt_plus: 'numpy.ndarray' object has no attribute 'cpu'
#
# === Résultats sauvegardés ===
# Métriques: results/results_bank/ftt_plus/seed_0/interpretable_ftt_plus_metrics_seed_0.json
# Importance: results/results_bank/ftt_plus/seed_0/interpretable_ftt_plus_importance_seed_0.json
# Visualisations: results/results_bank/ftt_plus/seed_0/interpretable_ftt_plus_{importance|attention}_seed_0.png
# Modèle: results/results_bank/ftt_plus/seed_0/interpretable_ftt_plus_weights_seed_0.pt
# Entraînement terminé!

# %% [markdown]
# ## Interpretable Sparse FT-T + Training

# %%
import os

# Changer vers le répertoire racine
os.chdir('/kaggle/working/customer-churn-ft_transformer')

# Utiliser PYTHONPATH pour que train.py trouve les modules
# !PYTHONPATH=/kaggle/working/customer-churn-ft_transformer python train/Bank/train_sparse_ftt_plus/train.py
# Out:
# Utilisation du device: cuda
# Seed: 0
# Données originales: 10000 lignes
# Après nettoyage: 10000 lignes (0 supprimées)
#
# Informations sur les features:
# Features numériques (6): ['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'EstimatedSalary']
# Variables catégorielles (4): ['Geography', 'Gender', 'HasCrCard', 'IsActiveMember']
# Cardinalités des variables catégorielles: [3, 2, 2, 2]
# Distribution des classes: [7963 2037]
# Tailles des ensembles:
# Train: 6800 | Val: 1200 | Test: 2000
# Configuration du modèle:
#   - Features numériques: 6
#   - Features catégorielles: 4 (cardinalités: [3, 2, 2, 2])
#   - Taille des tokens: 128
# Type d'embedding numérique: T
# /usr/local/lib/python3.11/dist-packages/rtdl_num_embeddings.py:499: UserWarning: Computing tree-based bins involves the conversion of the input PyTorch tensors to NumPy arrays. The provided PyTorch tensors are not located on CPU, so the conversion has some overhead.
#   warnings.warn(
# Nombre de paramètres: 504,065
#
# === Début de l'entraînement ===
# Epoch 000 | Training loss: 0.5547
# Epoch 000 | Validation loss: 0.4741
# Epoch 000 completed in 23.06s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.4741)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.7205, AUC-PR: 0.4288, Accuracy: 0.7965, B_ACC : 0.5, MCC: 0.0, Sensitivity/Recall: 0.0, Specificity: 1.0, Precision: 0.0, F1-score: 0.0, CK-score 0.0
# Test Performance:
#   ROC-AUC: 0.7205 | PR-AUC: 0.4288 | Accuracy: 0.7965
#   F1: 0.0000 | MCC: 0.0000 | Balanced Acc: 0.5000
# ------------------------------------------------------------
# Epoch 001 | Training loss: 0.4695
# Epoch 001 | Validation loss: 0.4375
# Epoch 001 completed in 22.70s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.4375)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.7681, AUC-PR: 0.4953, Accuracy: 0.7975, B_ACC : 0.5034, MCC: 0.0608, Sensitivity/Recall: 0.0074, Specificity: 0.9994, Precision: 0.75, F1-score: 0.0147, CK-score 0.0107
# Test Performance:
#   ROC-AUC: 0.7681 | PR-AUC: 0.4953 | Accuracy: 0.7975
#   F1: 0.0147 | MCC: 0.0608 | Balanced Acc: 0.5034
# ------------------------------------------------------------
# Epoch 002 | Training loss: 0.4415
# Epoch 002 | Validation loss: 0.4135
# Epoch 002 completed in 22.70s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.4135)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.7851, AUC-PR: 0.528, Accuracy: 0.818, B_ACC : 0.5784, MCC: 0.2912, Sensitivity/Recall: 0.1744, Specificity: 0.9824, Precision: 0.7172, F1-score: 0.2806, CK-score 0.2184
# Test Performance:
#   ROC-AUC: 0.7851 | PR-AUC: 0.5280 | Accuracy: 0.8180
#   F1: 0.2806 | MCC: 0.2912 | Balanced Acc: 0.5784
# ------------------------------------------------------------
# Epoch 003 | Training loss: 0.4184
# Epoch 003 | Validation loss: 0.4024
# Epoch 003 completed in 22.50s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.4024)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.7971, AUC-PR: 0.5535, Accuracy: 0.8265, B_ACC : 0.6194, MCC: 0.3545, Sensitivity/Recall: 0.2703, Specificity: 0.9686, Precision: 0.6875, F1-score: 0.388, CK-score 0.3086
# Test Performance:
#   ROC-AUC: 0.7971 | PR-AUC: 0.5535 | Accuracy: 0.8265
#   F1: 0.3880 | MCC: 0.3545 | Balanced Acc: 0.6194
# ------------------------------------------------------------
# Epoch 004 | Training loss: 0.4068
# Epoch 004 | Validation loss: 0.3956
# Epoch 004 completed in 22.21s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.3956)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8047, AUC-PR: 0.5695, Accuracy: 0.833, B_ACC : 0.64, MCC: 0.3909, Sensitivity/Recall: 0.3145, Specificity: 0.9655, Precision: 0.6995, F1-score: 0.4339, CK-score 0.3521
# Test Performance:
#   ROC-AUC: 0.8047 | PR-AUC: 0.5695 | Accuracy: 0.8330
#   F1: 0.4339 | MCC: 0.3909 | Balanced Acc: 0.6400
# ------------------------------------------------------------
# Epoch 005 | Training loss: 0.4007
# Epoch 005 | Validation loss: 0.3921
# Epoch 005 completed in 22.51s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.3921)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8132, AUC-PR: 0.5861, Accuracy: 0.834, B_ACC : 0.6406, MCC: 0.3946, Sensitivity/Recall: 0.3145, Specificity: 0.9667, Precision: 0.7072, F1-score: 0.4354, CK-score 0.3545
# Test Performance:
#   ROC-AUC: 0.8132 | PR-AUC: 0.5861 | Accuracy: 0.8340
#   F1: 0.4354 | MCC: 0.3946 | Balanced Acc: 0.6406
# ------------------------------------------------------------
# Epoch 006 | Training loss: 0.3947
# Epoch 006 | Validation loss: 0.3911
# Epoch 006 completed in 22.37s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.3911)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8182, AUC-PR: 0.594, Accuracy: 0.838, B_ACC : 0.6486, MCC: 0.413, Sensitivity/Recall: 0.3292, Specificity: 0.968, Precision: 0.7243, F1-score: 0.4527, CK-score 0.3729
# Test Performance:
#   ROC-AUC: 0.8182 | PR-AUC: 0.5940 | Accuracy: 0.8380
#   F1: 0.4527 | MCC: 0.4130 | Balanced Acc: 0.6486
# ------------------------------------------------------------
# Epoch 007 | Training loss: 0.3903
# Epoch 007 | Validation loss: 0.3854
# Epoch 007 completed in 22.38s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.3854)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.824, AUC-PR: 0.6048, Accuracy: 0.841, B_ACC : 0.6578, MCC: 0.4284, Sensitivity/Recall: 0.3489, Specificity: 0.9667, Precision: 0.7282, F1-score: 0.4718, CK-score 0.3915
# Test Performance:
#   ROC-AUC: 0.8240 | PR-AUC: 0.6048 | Accuracy: 0.8410
#   F1: 0.4718 | MCC: 0.4284 | Balanced Acc: 0.6578
# ------------------------------------------------------------
# Epoch 008 | Training loss: 0.3862
# Epoch 008 | Validation loss: 0.3828
# Epoch 008 completed in 22.27s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.3828)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.828, AUC-PR: 0.6121, Accuracy: 0.839, B_ACC : 0.6575, MCC: 0.4217, Sensitivity/Recall: 0.3514, Specificity: 0.9636, Precision: 0.7114, F1-score: 0.4704, CK-score 0.3881
# Test Performance:
#   ROC-AUC: 0.8280 | PR-AUC: 0.6121 | Accuracy: 0.8390
#   F1: 0.4704 | MCC: 0.4217 | Balanced Acc: 0.6575
# ------------------------------------------------------------
# Epoch 009 | Training loss: 0.3845
# Epoch 009 | Validation loss: 0.3799
# Epoch 009 completed in 22.61s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.3799)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8319, AUC-PR: 0.6207, Accuracy: 0.8425, B_ACC : 0.6615, MCC: 0.4354, Sensitivity/Recall: 0.3563, Specificity: 0.9667, Precision: 0.7323, F1-score: 0.4794, CK-score 0.3993
# Test Performance:
#   ROC-AUC: 0.8319 | PR-AUC: 0.6207 | Accuracy: 0.8425
#   F1: 0.4794 | MCC: 0.4354 | Balanced Acc: 0.6615
# ------------------------------------------------------------
# Epoch 010 | Training loss: 0.3753
# Epoch 010 | Validation loss: 0.3764
# Epoch 010 completed in 22.60s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.3764)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8348, AUC-PR: 0.6266, Accuracy: 0.8435, B_ACC : 0.6676, MCC: 0.4421, Sensitivity/Recall: 0.371, Specificity: 0.9642, Precision: 0.726, F1-score: 0.4911, CK-score 0.4098
# Test Performance:
#   ROC-AUC: 0.8348 | PR-AUC: 0.6266 | Accuracy: 0.8435
#   F1: 0.4911 | MCC: 0.4421 | Balanced Acc: 0.6676
# ------------------------------------------------------------
# Epoch 011 | Training loss: 0.3724
# Epoch 011 | Validation loss: 0.3742
# Epoch 011 completed in 22.60s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.3742)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8381, AUC-PR: 0.6345, Accuracy: 0.8455, B_ACC : 0.6689, MCC: 0.4493, Sensitivity/Recall: 0.371, Specificity: 0.9667, Precision: 0.7402, F1-score: 0.4943, CK-score 0.4147
# Test Performance:
#   ROC-AUC: 0.8381 | PR-AUC: 0.6345 | Accuracy: 0.8455
#   F1: 0.4943 | MCC: 0.4493 | Balanced Acc: 0.6689
# ------------------------------------------------------------
# Epoch 012 | Training loss: 0.3699
# Epoch 012 | Validation loss: 0.3734
# Epoch 012 completed in 22.39s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.3734)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8401, AUC-PR: 0.6407, Accuracy: 0.8465, B_ACC : 0.6722, MCC: 0.4543, Sensitivity/Recall: 0.3784, Specificity: 0.9661, Precision: 0.7404, F1-score: 0.5008, CK-score 0.4211
# Test Performance:
#   ROC-AUC: 0.8401 | PR-AUC: 0.6407 | Accuracy: 0.8465
#   F1: 0.5008 | MCC: 0.4543 | Balanced Acc: 0.6722
# ------------------------------------------------------------
# Epoch 013 | Training loss: 0.3681
# Epoch 013 | Validation loss: 0.3716
# Epoch 013 completed in 22.59s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.3716)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8423, AUC-PR: 0.6479, Accuracy: 0.8505, B_ACC : 0.6738, MCC: 0.4687, Sensitivity/Recall: 0.3759, Specificity: 0.9718, Precision: 0.7727, F1-score: 0.5058, CK-score 0.4298
# Test Performance:
#   ROC-AUC: 0.8423 | PR-AUC: 0.6479 | Accuracy: 0.8505
#   F1: 0.5058 | MCC: 0.4687 | Balanced Acc: 0.6738
# ------------------------------------------------------------
# Epoch 014 | Training loss: 0.3644
# Epoch 014 | Validation loss: 0.3699
# Epoch 014 completed in 22.37s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.3699)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8439, AUC-PR: 0.6545, Accuracy: 0.853, B_ACC : 0.6772, MCC: 0.4789, Sensitivity/Recall: 0.3808, Specificity: 0.9736, Precision: 0.7868, F1-score: 0.5132, CK-score 0.4387
# Test Performance:
#   ROC-AUC: 0.8439 | PR-AUC: 0.6545 | Accuracy: 0.8530
#   F1: 0.5132 | MCC: 0.4789 | Balanced Acc: 0.6772
# ------------------------------------------------------------
# Epoch 015 | Training loss: 0.3638
# Epoch 015 | Validation loss: 0.3699
# Epoch 015 completed in 22.42s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.3699)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8458, AUC-PR: 0.6592, Accuracy: 0.853, B_ACC : 0.6772, MCC: 0.4789, Sensitivity/Recall: 0.3808, Specificity: 0.9736, Precision: 0.7868, F1-score: 0.5132, CK-score 0.4387
# Test Performance:
#   ROC-AUC: 0.8458 | PR-AUC: 0.6592 | Accuracy: 0.8530
#   F1: 0.5132 | MCC: 0.4789 | Balanced Acc: 0.6772
# ------------------------------------------------------------
# Epoch 016 | Training loss: 0.3611
# Epoch 016 | Validation loss: 0.3647
# Epoch 016 completed in 22.46s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.3647)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8462, AUC-PR: 0.6613, Accuracy: 0.8535, B_ACC : 0.6849, MCC: 0.4835, Sensitivity/Recall: 0.4005, Specificity: 0.9692, Precision: 0.7689, F1-score: 0.5267, CK-score 0.45
# Test Performance:
#   ROC-AUC: 0.8462 | PR-AUC: 0.6613 | Accuracy: 0.8535
#   F1: 0.5267 | MCC: 0.4835 | Balanced Acc: 0.6849
# ------------------------------------------------------------
# Epoch 017 | Training loss: 0.3620
# Epoch 017 | Validation loss: 0.3640
# Epoch 017 completed in 22.35s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.3640)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.848, AUC-PR: 0.6665, Accuracy: 0.8565, B_ACC : 0.6895, MCC: 0.4957, Sensitivity/Recall: 0.4079, Specificity: 0.9711, Precision: 0.783, F1-score: 0.5364, CK-score 0.4613
# Test Performance:
#   ROC-AUC: 0.8480 | PR-AUC: 0.6665 | Accuracy: 0.8565
#   F1: 0.5364 | MCC: 0.4957 | Balanced Acc: 0.6895
# ------------------------------------------------------------
# Epoch 018 | Training loss: 0.3587
# Epoch 018 | Validation loss: 0.3617
# Epoch 018 completed in 22.45s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.3617)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8485, AUC-PR: 0.6689, Accuracy: 0.8555, B_ACC : 0.6907, MCC: 0.4927, Sensitivity/Recall: 0.4128, Specificity: 0.9686, Precision: 0.7706, F1-score: 0.5376, CK-score 0.4611
# Test Performance:
#   ROC-AUC: 0.8485 | PR-AUC: 0.6689 | Accuracy: 0.8555
#   F1: 0.5376 | MCC: 0.4927 | Balanced Acc: 0.6907
# ------------------------------------------------------------
# Epoch 019 | Training loss: 0.3534
# Epoch 019 | Validation loss: 0.3643
# Epoch 019 completed in 22.23s
# ------------------------------------------------------------
# Epoch 020 | Training loss: 0.3510
# Epoch 020 | Validation loss: 0.3642
# Epoch 020 completed in 22.43s
# ------------------------------------------------------------
# Epoch 021 | Training loss: 0.3550
# Epoch 021 | Validation loss: 0.3597
# Epoch 021 completed in 22.67s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.3597)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8497, AUC-PR: 0.6738, Accuracy: 0.8545, B_ACC : 0.6919, MCC: 0.49, Sensitivity/Recall: 0.4177, Specificity: 0.9661, Precision: 0.7589, F1-score: 0.5388, CK-score 0.4609
# Test Performance:
#   ROC-AUC: 0.8497 | PR-AUC: 0.6738 | Accuracy: 0.8545
#   F1: 0.5388 | MCC: 0.4900 | Balanced Acc: 0.6919
# ------------------------------------------------------------
# Epoch 022 | Training loss: 0.3506
# Epoch 022 | Validation loss: 0.3621
# Epoch 022 completed in 22.52s
# ------------------------------------------------------------
# Epoch 023 | Training loss: 0.3466
# Epoch 023 | Validation loss: 0.3592
# Epoch 023 completed in 22.42s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.3592)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.85, AUC-PR: 0.6765, Accuracy: 0.8585, B_ACC : 0.7017, MCC: 0.5072, Sensitivity/Recall: 0.4373, Specificity: 0.9661, Precision: 0.7672, F1-score: 0.5571, CK-score 0.4803
# Test Performance:
#   ROC-AUC: 0.8500 | PR-AUC: 0.6765 | Accuracy: 0.8585
#   F1: 0.5571 | MCC: 0.5072 | Balanced Acc: 0.7017
# ------------------------------------------------------------
# Epoch 024 | Training loss: 0.3480
# Epoch 024 | Validation loss: 0.3603
# Epoch 024 completed in 22.58s
# ------------------------------------------------------------
# Epoch 025 | Training loss: 0.3423
# Epoch 025 | Validation loss: 0.3595
# Epoch 025 completed in 22.42s
# ------------------------------------------------------------
# Epoch 026 | Training loss: 0.3468
# Epoch 026 | Validation loss: 0.3583
# Epoch 026 completed in 22.57s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.3583)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8505, AUC-PR: 0.6798, Accuracy: 0.8585, B_ACC : 0.7017, MCC: 0.5072, Sensitivity/Recall: 0.4373, Specificity: 0.9661, Precision: 0.7672, F1-score: 0.5571, CK-score 0.4803
# Test Performance:
#   ROC-AUC: 0.8505 | PR-AUC: 0.6798 | Accuracy: 0.8585
#   F1: 0.5571 | MCC: 0.5072 | Balanced Acc: 0.7017
# ------------------------------------------------------------
# Epoch 027 | Training loss: 0.3460
# Epoch 027 | Validation loss: 0.3579
# Epoch 027 completed in 22.31s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.3579)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8505, AUC-PR: 0.6798, Accuracy: 0.859, B_ACC : 0.703, MCC: 0.5094, Sensitivity/Recall: 0.4398, Specificity: 0.9661, Precision: 0.7682, F1-score: 0.5594, CK-score 0.4827
# Test Performance:
#   ROC-AUC: 0.8505 | PR-AUC: 0.6798 | Accuracy: 0.8590
#   F1: 0.5594 | MCC: 0.5094 | Balanced Acc: 0.7030
# ------------------------------------------------------------
# Epoch 028 | Training loss: 0.3465
# Epoch 028 | Validation loss: 0.3579
# Epoch 028 completed in 22.43s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.3579)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.851, AUC-PR: 0.6801, Accuracy: 0.8595, B_ACC : 0.7042, MCC: 0.5115, Sensitivity/Recall: 0.4423, Specificity: 0.9661, Precision: 0.7692, F1-score: 0.5616, CK-score 0.4851
# Test Performance:
#   ROC-AUC: 0.8510 | PR-AUC: 0.6801 | Accuracy: 0.8595
#   F1: 0.5616 | MCC: 0.5115 | Balanced Acc: 0.7042
# ------------------------------------------------------------
# Epoch 029 | Training loss: 0.3429
# Epoch 029 | Validation loss: 0.3576
# Epoch 029 completed in 22.36s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.3576)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8517, AUC-PR: 0.6814, Accuracy: 0.859, B_ACC : 0.7039, MCC: 0.5098, Sensitivity/Recall: 0.4423, Specificity: 0.9655, Precision: 0.766, F1-score: 0.5608, CK-score 0.4839
# Test Performance:
#   ROC-AUC: 0.8517 | PR-AUC: 0.6814 | Accuracy: 0.8590
#   F1: 0.5608 | MCC: 0.5098 | Balanced Acc: 0.7039
# ------------------------------------------------------------
# Epoch 030 | Training loss: 0.3433
# Epoch 030 | Validation loss: 0.3587
# Epoch 030 completed in 22.34s
# ------------------------------------------------------------
# Epoch 031 | Training loss: 0.3422
# Epoch 031 | Validation loss: 0.3593
# Epoch 031 completed in 22.20s
# ------------------------------------------------------------
# Epoch 032 | Training loss: 0.3448
# Epoch 032 | Validation loss: 0.3582
# Epoch 032 completed in 22.59s
# ------------------------------------------------------------
# Epoch 033 | Training loss: 0.3421
# Epoch 033 | Validation loss: 0.3571
# Epoch 033 completed in 22.33s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.3571)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8518, AUC-PR: 0.682, Accuracy: 0.86, B_ACC : 0.7045, MCC: 0.5132, Sensitivity/Recall: 0.4423, Specificity: 0.9667, Precision: 0.7725, F1-score: 0.5625, CK-score 0.4864
# Test Performance:
#   ROC-AUC: 0.8518 | PR-AUC: 0.6820 | Accuracy: 0.8600
#   F1: 0.5625 | MCC: 0.5132 | Balanced Acc: 0.7045
# ------------------------------------------------------------
# Epoch 034 | Training loss: 0.3390
# Epoch 034 | Validation loss: 0.3570
# Epoch 034 completed in 22.63s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.3570)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8515, AUC-PR: 0.6821, Accuracy: 0.8605, B_ACC : 0.7048, MCC: 0.515, Sensitivity/Recall: 0.4423, Specificity: 0.9674, Precision: 0.7759, F1-score: 0.5634, CK-score 0.4877
# Test Performance:
#   ROC-AUC: 0.8515 | PR-AUC: 0.6821 | Accuracy: 0.8605
#   F1: 0.5634 | MCC: 0.5150 | Balanced Acc: 0.7048
# ------------------------------------------------------------
# Epoch 035 | Training loss: 0.3396
# Epoch 035 | Validation loss: 0.3584
# Epoch 035 completed in 22.61s
# ------------------------------------------------------------
# Epoch 036 | Training loss: 0.3400
# Epoch 036 | Validation loss: 0.3580
# Epoch 036 completed in 22.72s
# ------------------------------------------------------------
# Epoch 037 | Training loss: 0.3425
# Epoch 037 | Validation loss: 0.3579
# Epoch 037 completed in 22.68s
# ------------------------------------------------------------
# Epoch 038 | Training loss: 0.3402
# Epoch 038 | Validation loss: 0.3581
# Epoch 038 completed in 22.65s
# ------------------------------------------------------------
# Epoch 039 | Training loss: 0.3364
# Epoch 039 | Validation loss: 0.3579
# Epoch 039 completed in 22.75s
# ------------------------------------------------------------
# Epoch 040 | Training loss: 0.3407
# Epoch 040 | Validation loss: 0.3562
# Epoch 040 completed in 22.59s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.3562)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8521, AUC-PR: 0.6825, Accuracy: 0.861, B_ACC : 0.706, MCC: 0.5171, Sensitivity/Recall: 0.4447, Specificity: 0.9674, Precision: 0.7768, F1-score: 0.5656, CK-score 0.4901
# Test Performance:
#   ROC-AUC: 0.8521 | PR-AUC: 0.6825 | Accuracy: 0.8610
#   F1: 0.5656 | MCC: 0.5171 | Balanced Acc: 0.7060
# ------------------------------------------------------------
# Epoch 041 | Training loss: 0.3364
# Epoch 041 | Validation loss: 0.3564
# Epoch 041 completed in 22.50s
# ------------------------------------------------------------
# Epoch 042 | Training loss: 0.3368
# Epoch 042 | Validation loss: 0.3574
# Epoch 042 completed in 22.32s
# ------------------------------------------------------------
# Epoch 043 | Training loss: 0.3367
# Epoch 043 | Validation loss: 0.3570
# Epoch 043 completed in 22.55s
# ------------------------------------------------------------
# Epoch 044 | Training loss: 0.3334
# Epoch 044 | Validation loss: 0.3567
# Epoch 044 completed in 22.17s
# ------------------------------------------------------------
# Epoch 045 | Training loss: 0.3356
# Epoch 045 | Validation loss: 0.3552
# Epoch 045 completed in 22.71s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.3552)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8529, AUC-PR: 0.6831, Accuracy: 0.859, B_ACC : 0.7048, MCC: 0.5102, Sensitivity/Recall: 0.4447, Specificity: 0.9648, Precision: 0.7637, F1-score: 0.5621, CK-score 0.485
# Test Performance:
#   ROC-AUC: 0.8529 | PR-AUC: 0.6831 | Accuracy: 0.8590
#   F1: 0.5621 | MCC: 0.5102 | Balanced Acc: 0.7048
# ------------------------------------------------------------
# Epoch 046 | Training loss: 0.3372
# Epoch 046 | Validation loss: 0.3570
# Epoch 046 completed in 22.71s
# ------------------------------------------------------------
# Epoch 047 | Training loss: 0.3353
# Epoch 047 | Validation loss: 0.3564
# Epoch 047 completed in 22.75s
# ------------------------------------------------------------
# Epoch 048 | Training loss: 0.3359
# Epoch 048 | Validation loss: 0.3570
# Epoch 048 completed in 22.67s
# ------------------------------------------------------------
# Epoch 049 | Training loss: 0.3317
# Epoch 049 | Validation loss: 0.3576
# Epoch 049 completed in 22.55s
# ------------------------------------------------------------
# Epoch 050 | Training loss: 0.3318
# Epoch 050 | Validation loss: 0.3578
# Epoch 050 completed in 22.94s
# ------------------------------------------------------------
# Epoch 051 | Training loss: 0.3335
# Epoch 051 | Validation loss: 0.3568
# Epoch 051 completed in 22.19s
# ------------------------------------------------------------
# Epoch 052 | Training loss: 0.3343
# Epoch 052 | Validation loss: 0.3574
# Epoch 052 completed in 22.10s
# ------------------------------------------------------------
# Epoch 053 | Training loss: 0.3290
# Epoch 053 | Validation loss: 0.3566
# Epoch 053 completed in 22.21s
# ------------------------------------------------------------
# Epoch 054 | Training loss: 0.3329
# Epoch 054 | Validation loss: 0.3566
# Epoch 054 completed in 21.97s
# ------------------------------------------------------------
# Epoch 055 | Training loss: 0.3318
# Epoch 055 | Validation loss: 0.3574
# Epoch 055 completed in 22.23s
# ------------------------------------------------------------
# Epoch 056 | Training loss: 0.3315
# Epoch 056 | Validation loss: 0.3574
# Epoch 056 completed in 22.64s
# ------------------------------------------------------------
# Epoch 057 | Training loss: 0.3289
# Epoch 057 | Validation loss: 0.3575
# Epoch 057 completed in 22.76s
# ------------------------------------------------------------
# Epoch 058 | Training loss: 0.3344
# Epoch 058 | Validation loss: 0.3554
# Epoch 058 completed in 22.28s
# ------------------------------------------------------------
# Epoch 059 | Training loss: 0.3323
# Epoch 059 | Validation loss: 0.3551
# Epoch 059 completed in 22.42s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.3551)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8523, AUC-PR: 0.6822, Accuracy: 0.86, B_ACC : 0.7054, MCC: 0.5136, Sensitivity/Recall: 0.4447, Specificity: 0.9661, Precision: 0.7702, F1-score: 0.5638, CK-score 0.4875
# Test Performance:
#   ROC-AUC: 0.8523 | PR-AUC: 0.6822 | Accuracy: 0.8600
#   F1: 0.5638 | MCC: 0.5136 | Balanced Acc: 0.7054
# ------------------------------------------------------------
# Epoch 060 | Training loss: 0.3309
# Epoch 060 | Validation loss: 0.3548
# Epoch 060 completed in 22.58s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.3548)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8528, AUC-PR: 0.683, Accuracy: 0.8595, B_ACC : 0.706, MCC: 0.5123, Sensitivity/Recall: 0.4472, Specificity: 0.9648, Precision: 0.7647, F1-score: 0.5644, CK-score 0.4874
# Test Performance:
#   ROC-AUC: 0.8528 | PR-AUC: 0.6830 | Accuracy: 0.8595
#   F1: 0.5644 | MCC: 0.5123 | Balanced Acc: 0.7060
# ------------------------------------------------------------
# Epoch 061 | Training loss: 0.3297
# Epoch 061 | Validation loss: 0.3562
# Epoch 061 completed in 22.47s
# ------------------------------------------------------------
# Epoch 062 | Training loss: 0.3322
# Epoch 062 | Validation loss: 0.3540
# Epoch 062 completed in 22.06s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.3540)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8529, AUC-PR: 0.6828, Accuracy: 0.859, B_ACC : 0.7066, MCC: 0.511, Sensitivity/Recall: 0.4496, Specificity: 0.9636, Precision: 0.7593, F1-score: 0.5648, CK-score 0.4872
# Test Performance:
#   ROC-AUC: 0.8529 | PR-AUC: 0.6828 | Accuracy: 0.8590
#   F1: 0.5648 | MCC: 0.5110 | Balanced Acc: 0.7066
# ------------------------------------------------------------
# Epoch 063 | Training loss: 0.3288
# Epoch 063 | Validation loss: 0.3557
# Epoch 063 completed in 21.43s
# ------------------------------------------------------------
# Epoch 064 | Training loss: 0.3292
# Epoch 064 | Validation loss: 0.3563
# Epoch 064 completed in 21.65s
# ------------------------------------------------------------
# Epoch 065 | Training loss: 0.3271
# Epoch 065 | Validation loss: 0.3555
# Epoch 065 completed in 21.62s
# ------------------------------------------------------------
# Epoch 066 | Training loss: 0.3308
# Epoch 066 | Validation loss: 0.3556
# Epoch 066 completed in 21.59s
# ------------------------------------------------------------
# Epoch 067 | Training loss: 0.3302
# Epoch 067 | Validation loss: 0.3553
# Epoch 067 completed in 21.42s
# ------------------------------------------------------------
# Epoch 068 | Training loss: 0.3297
# Epoch 068 | Validation loss: 0.3556
# Epoch 068 completed in 21.97s
# ------------------------------------------------------------
# Epoch 069 | Training loss: 0.3304
# Epoch 069 | Validation loss: 0.3548
# Epoch 069 completed in 21.80s
# ------------------------------------------------------------
# Epoch 070 | Training loss: 0.3299
# Epoch 070 | Validation loss: 0.3548
# Epoch 070 completed in 22.23s
# ------------------------------------------------------------
# Epoch 071 | Training loss: 0.3250
# Epoch 071 | Validation loss: 0.3539
# Epoch 071 completed in 22.41s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.3539)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8532, AUC-PR: 0.6815, Accuracy: 0.8585, B_ACC : 0.7063, MCC: 0.5093, Sensitivity/Recall: 0.4496, Specificity: 0.963, Precision: 0.7562, F1-score: 0.5639, CK-score 0.4859
# Test Performance:
#   ROC-AUC: 0.8532 | PR-AUC: 0.6815 | Accuracy: 0.8585
#   F1: 0.5639 | MCC: 0.5093 | Balanced Acc: 0.7063
# ------------------------------------------------------------
# Epoch 072 | Training loss: 0.3305
# Epoch 072 | Validation loss: 0.3533
# Epoch 072 completed in 22.23s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.3533)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8533, AUC-PR: 0.6822, Accuracy: 0.8575, B_ACC : 0.7066, MCC: 0.5065, Sensitivity/Recall: 0.4521, Specificity: 0.9611, Precision: 0.748, F1-score: 0.5636, CK-score 0.4845
# Test Performance:
#   ROC-AUC: 0.8533 | PR-AUC: 0.6822 | Accuracy: 0.8575
#   F1: 0.5636 | MCC: 0.5065 | Balanced Acc: 0.7066
# ------------------------------------------------------------
# Epoch 073 | Training loss: 0.3281
# Epoch 073 | Validation loss: 0.3550
# Epoch 073 completed in 22.37s
# ------------------------------------------------------------
# Epoch 074 | Training loss: 0.3265
# Epoch 074 | Validation loss: 0.3548
# Epoch 074 completed in 22.22s
# ------------------------------------------------------------
# Epoch 075 | Training loss: 0.3282
# Epoch 075 | Validation loss: 0.3540
# Epoch 075 completed in 22.36s
# ------------------------------------------------------------
# Epoch 076 | Training loss: 0.3275
# Epoch 076 | Validation loss: 0.3544
# Epoch 076 completed in 21.90s
# ------------------------------------------------------------
# Epoch 077 | Training loss: 0.3262
# Epoch 077 | Validation loss: 0.3539
# Epoch 077 completed in 21.81s
# ------------------------------------------------------------
# Epoch 078 | Training loss: 0.3294
# Epoch 078 | Validation loss: 0.3531
# Epoch 078 completed in 22.10s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.3531)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8531, AUC-PR: 0.6832, Accuracy: 0.8555, B_ACC : 0.6989, MCC: 0.4965, Sensitivity/Recall: 0.4349, Specificity: 0.963, Precision: 0.75, F1-score: 0.5506, CK-score 0.4716
# Test Performance:
#   ROC-AUC: 0.8531 | PR-AUC: 0.6832 | Accuracy: 0.8555
#   F1: 0.5506 | MCC: 0.4965 | Balanced Acc: 0.6989
# ------------------------------------------------------------
# Epoch 079 | Training loss: 0.3267
# Epoch 079 | Validation loss: 0.3547
# Epoch 079 completed in 22.07s
# ------------------------------------------------------------
# Epoch 080 | Training loss: 0.3256
# Epoch 080 | Validation loss: 0.3550
# Epoch 080 completed in 22.19s
# ------------------------------------------------------------
# Epoch 081 | Training loss: 0.3243
# Epoch 081 | Validation loss: 0.3560
# Epoch 081 completed in 22.02s
# ------------------------------------------------------------
# Epoch 082 | Training loss: 0.3260
# Epoch 082 | Validation loss: 0.3548
# Epoch 082 completed in 22.34s
# ------------------------------------------------------------
# Epoch 083 | Training loss: 0.3267
# Epoch 083 | Validation loss: 0.3545
# Epoch 083 completed in 22.23s
# ------------------------------------------------------------
# Epoch 084 | Training loss: 0.3254
# Epoch 084 | Validation loss: 0.3545
# Epoch 084 completed in 22.21s
# ------------------------------------------------------------
# Epoch 085 | Training loss: 0.3267
# Epoch 085 | Validation loss: 0.3559
# Epoch 085 completed in 21.91s
# ------------------------------------------------------------
# Epoch 086 | Training loss: 0.3232
# Epoch 086 | Validation loss: 0.3567
# Epoch 086 completed in 22.12s
# ------------------------------------------------------------
# Epoch 087 | Training loss: 0.3246
# Epoch 087 | Validation loss: 0.3565
# Epoch 087 completed in 21.80s
# ------------------------------------------------------------
# Epoch 088 | Training loss: 0.3230
# Epoch 088 | Validation loss: 0.3558
# Epoch 088 completed in 22.15s
# ------------------------------------------------------------
# Epoch 089 | Training loss: 0.3256
# Epoch 089 | Validation loss: 0.3563
# Epoch 089 completed in 21.95s
# ------------------------------------------------------------
# Epoch 090 | Training loss: 0.3228
# Epoch 090 | Validation loss: 0.3571
# Epoch 090 completed in 21.99s
# ------------------------------------------------------------
# Epoch 091 | Training loss: 0.3216
# Epoch 091 | Validation loss: 0.3587
# Epoch 091 completed in 22.02s
# ------------------------------------------------------------
# Epoch 092 | Training loss: 0.3234
# Epoch 092 | Validation loss: 0.3591
# Epoch 092 completed in 21.88s
# ------------------------------------------------------------
# Epoch 093 | Training loss: 0.3224
# Epoch 093 | Validation loss: 0.3582
# Epoch 093 completed in 22.06s
# ------------------------------------------------------------
# Epoch 094 | Training loss: 0.3243
# Epoch 094 | Validation loss: 0.3579
# Epoch 094 completed in 22.56s
# ------------------------------------------------------------
# Epoch 095 | Training loss: 0.3238
# Epoch 095 | Validation loss: 0.3575
# Epoch 095 completed in 22.00s
# ------------------------------------------------------------
# Epoch 096 | Training loss: 0.3213
# Epoch 096 | Validation loss: 0.3585
# Epoch 096 completed in 22.01s
# ------------------------------------------------------------
# Epoch 097 | Training loss: 0.3213
# Epoch 097 | Validation loss: 0.3589
# Epoch 097 completed in 22.08s
# ------------------------------------------------------------
# Epoch 098 | Training loss: 0.3218
# Epoch 098 | Validation loss: 0.3584
# Epoch 098 completed in 22.27s
# ------------------------------------------------------------
# Epoch 099 | Training loss: 0.3220
# Epoch 099 | Validation loss: 0.3569
# Epoch 099 completed in 22.51s
# ------------------------------------------------------------
# Epoch 100 | Training loss: 0.3217
# Epoch 100 | Validation loss: 0.3585
# Epoch 100 completed in 22.14s
# ------------------------------------------------------------
# Epoch 101 | Training loss: 0.3248
# Epoch 101 | Validation loss: 0.3576
# Epoch 101 completed in 22.26s
# ------------------------------------------------------------
# Epoch 102 | Training loss: 0.3199
# Epoch 102 | Validation loss: 0.3576
# Epoch 102 completed in 22.32s
# ------------------------------------------------------------
# Epoch 103 | Training loss: 0.3180
# Epoch 103 | Validation loss: 0.3580
# Epoch 103 completed in 22.47s
# ------------------------------------------------------------
# Epoch 104 | Training loss: 0.3203
# Epoch 104 | Validation loss: 0.3577
# Epoch 104 completed in 22.59s
# ------------------------------------------------------------
# Epoch 105 | Training loss: 0.3217
# Epoch 105 | Validation loss: 0.3580
# Epoch 105 completed in 22.49s
# ------------------------------------------------------------
# Epoch 106 | Training loss: 0.3213
# Epoch 106 | Validation loss: 0.3588
# Epoch 106 completed in 22.51s
# ------------------------------------------------------------
# Epoch 107 | Training loss: 0.3213
# Epoch 107 | Validation loss: 0.3581
# Epoch 107 completed in 22.20s
#
# Early stopping à l'époque 107 (patience: 29)
#
# Meilleur modèle chargé (époque 78, val_loss: 0.3531)
#
# === Évaluation finale ===
# Performance sur l'ensemble de validation:
# Performance for test_dataset
# AUC-ROC: 0.8597, AUC-PR: 0.6648, Accuracy: 0.8567, B_ACC : 0.7086, MCC: 0.5048, Sensitivity/Recall: 0.459, Specificity: 0.9582, Precision: 0.7368, F1-score: 0.5656, CK-score 0.4853
# Val Performance:
#   ROC-AUC: 0.8597 | PR-AUC: 0.6648 | Accuracy: 0.8567
#   F1: 0.5656 | MCC: 0.5048 | Balanced Acc: 0.7086
#
# Performance sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8528, AUC-PR: 0.6799, Accuracy: 0.8515, B_ACC : 0.6982, MCC: 0.4843, Sensitivity/Recall: 0.4398, Specificity: 0.9567, Precision: 0.7218, F1-score: 0.5466, CK-score 0.464
# Test Performance:
#   ROC-AUC: 0.8528 | PR-AUC: 0.6799 | Accuracy: 0.8515
#   F1: 0.5466 | MCC: 0.4843 | Balanced Acc: 0.6982
#
# === Analyse d'interprétabilité ===
#
# Top 10 features importantes:
#    1. Balance             : 0.1440
#    2. CreditScore         : 0.1287
#    3. Tenure              : 0.1114
#    4. EstimatedSalary     : 0.1062
#    5. Gender              : 0.0958
#    6. Age                 : 0.0947
#    7. HasCrCard           : 0.0886
#    8. Geography           : 0.0840
#    9. NumOfProducts       : 0.0825
#   10. IsActiveMember      : 0.0641
#
# Génération des visualisations...
# Graphique d'importance sauvegardé: results/results_bank/sparse_ftt_plus/seed_0/heatmaps/interpretable_sparse_ftt_plus_importance_seed_0.png
# Avertissement: Impossible de générer la heatmap d'attention pour interpretable_sparse_ftt_plus: 'numpy.ndarray' object has no attribute 'cpu'
#
# === Résultats sauvegardés ===
# Métriques: results/results_bank/sparse_ftt_plus/seed_0/interpretable_sparse_ftt_plus_metrics_seed_0.json
# Importance: results/results_bank/sparse_ftt_plus/seed_0/interpretable_sparse_ftt_plus_importance_seed_0.json
# Visualisations: results/results_bank/sparse_ftt_plus/seed_0/interpretable_sparse_ftt_plus_{importance|attention}_seed_0.png
# Modèle: results/results_bank/sparse_ftt_plus/seed_0/interpretable_sparse_ftt_plus_weights_seed_0.pt
# Entraînement terminé!

# %% [markdown]
# ## FT-T Model Optimized with Optuna

# %%
"""
import os

# Changer vers le répertoire racine
os.chdir('/kaggle/working/customer-churn-ft_transformer')

# Utiliser PYTHONPATH pour que train.py trouve les modules
# !PYTHONPATH=/kaggle/working/customer-churn-ft_transformer python train/Bank/train_ftt/experiment_with_optuna.py
"""
# Out:
# "\nimport os\n\n# Changer vers le répertoire racine\nos.chdir('/kaggle/working/customer-churn-ft_transformer')\n\n# Utiliser PYTHONPATH pour que train.py trouve les modules\n!PYTHONPATH=/kaggle/working/customer-churn-ft_transformer python train/Bank/train_ftt/experiment_with_optuna.py\n"

# %% [markdown]
# ## FT-T+ Model Optimized with Optuna

# %%
"""
import os

# Changer vers le répertoire racine
os.chdir('/kaggle/working/customer-churn-ft_transformer')

# Utiliser PYTHONPATH pour que train.py trouve les modules
# !PYTHONPATH=/kaggle/working/customer-churn-ft_transformer python train/Bank/train_ftt_plus/experiment_with_optuna.py
"""
# Out:
# "\nimport os\n\n# Changer vers le répertoire racine\nos.chdir('/kaggle/working/customer-churn-ft_transformer')\n\n# Utiliser PYTHONPATH pour que train.py trouve les modules\n!PYTHONPATH=/kaggle/working/customer-churn-ft_transformer python train/Bank/train_ftt_plus/experiment_with_optuna.py\n"

# %% [markdown]
# ## Sparse FT-T+ Model Optimized with Optuna

# %%
"""
import os

# Changer vers le répertoire racine
os.chdir('/kaggle/working/customer-churn-ft_transformer')

# Utiliser PYTHONPATH pour que train.py trouve les modules
# !PYTHONPATH=/kaggle/working/customer-churn-ft_transformer python train/Bank/train_sparse_ftt_plus/experiment_with_optuna.py
"""
# Out:
# "\nimport os\n\n# Changer vers le répertoire racine\nos.chdir('/kaggle/working/customer-churn-ft_transformer')\n\n# Utiliser PYTHONPATH pour que train.py trouve les modules\n!PYTHONPATH=/kaggle/working/customer-churn-ft_transformer python train/Bank/train_sparse_ftt_plus/experiment_with_optuna.py\n"

# %% [markdown]
# # Telecom Dataset

# %% [markdown]
# ## FT-T training

# %%
import os

# Changer vers le répertoire racine
os.chdir('/kaggle/working/customer-churn-ft_transformer')

# Utiliser PYTHONPATH pour que train.py trouve les modules
# !PYTHONPATH=/kaggle/working/customer-churn-ft_transformer python train/Telecom/train_ftt/train.py
# Out:
# Utilisation du device: cuda
# Seed: 0
# Données originales: 7043 lignes
# Après nettoyage: 7032 lignes (11 supprimées)
#
# Informations sur les features:
# Features numériques (3): ['tenure', 'MonthlyCharges', 'TotalCharges']
# Variables catégorielles (16): ['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod']
# Cardinalités des variables catégorielles: [2, 2, 2, 2, 2, 3, 3, 3, 3, 3, 3, 3, 3, 3, 2, 4]
# Distribution des classes: [5163 1869]
# Tailles des ensembles:
# Train: 4781 | Val: 844 | Test: 1407
# Traceback (most recent call last):
#   File "/kaggle/working/customer-churn-ft_transformer/train/Telecom/train_ftt/train.py", line 40, in <module>
#     model = FTTransformer.make_baseline(
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: FTTransformer.make_baseline() got an unexpected keyword argument 'attention_n_heads'

# %% [markdown]
# ## Interpretable FT-T + training

# %%
import os

# Changer vers le répertoire racine
os.chdir('/kaggle/working/customer-churn-ft_transformer')

# Utiliser PYTHONPATH pour que train.py trouve les modules
# !PYTHONPATH=/kaggle/working/customer-churn-ft_transformer python train/Telecom/train_ftt_plus/train.py
# Out:
# Utilisation du device: cuda
# Seed: 0
# Données originales: 7043 lignes
# Après nettoyage: 7032 lignes (11 supprimées)
#
# Informations sur les features:
# Features numériques (3): ['tenure', 'MonthlyCharges', 'TotalCharges']
# Variables catégorielles (16): ['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod']
# Cardinalités des variables catégorielles: [2, 2, 2, 2, 2, 3, 3, 3, 3, 3, 3, 3, 3, 3, 2, 4]
# Distribution des classes: [5163 1869]
# Tailles des ensembles:
# Train: 4781 | Val: 844 | Test: 1407
# Configuration du modèle:
#   - Features numériques: 3
#   - Features catégorielles: 16 (cardinalités: [2, 2, 2, 2, 2, 3, 3, 3, 3, 3, 3, 3, 3, 3, 2, 4])
#   - Taille des tokens: 128
# Type d'embedding numérique: T
# /usr/local/lib/python3.11/dist-packages/rtdl_num_embeddings.py:499: UserWarning: Computing tree-based bins involves the conversion of the input PyTorch tensors to NumPy arrays. The provided PyTorch tensors are not located on CPU, so the conversion has some overhead.
#   warnings.warn(
# Nombre de paramètres: 507,265
#
# === Début de l'entraînement ===
# Epoch 000 | Training loss: 0.6061
# Epoch 000 | Validation loss: 0.5297
# Epoch 000 completed in 10.28s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.5297)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.7822, AUC-PR: 0.5806, Accuracy: 0.7342, B_ACC : 0.5, MCC: 0.0, Sensitivity/Recall: 0.0, Specificity: 1.0, Precision: 0.0, F1-score: 0.0, CK-score 0.0
# Test Performance:
#   ROC-AUC: 0.7822 | PR-AUC: 0.5806 | Accuracy: 0.7342
#   F1: 0.0000 | MCC: 0.0000 | Balanced Acc: 0.5000
# ------------------------------------------------------------
# Epoch 001 | Training loss: 0.5179
# Epoch 001 | Validation loss: 0.4640
# Epoch 001 completed in 10.07s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.4640)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.825, AUC-PR: 0.6258, Accuracy: 0.7825, B_ACC : 0.625, MCC: 0.3601, Sensitivity/Recall: 0.2888, Specificity: 0.9613, Precision: 0.7297, F1-score: 0.4138, CK-score 0.3098
# Test Performance:
#   ROC-AUC: 0.8250 | PR-AUC: 0.6258 | Accuracy: 0.7825
#   F1: 0.4138 | MCC: 0.3601 | Balanced Acc: 0.6250
# ------------------------------------------------------------
# Epoch 002 | Training loss: 0.4709
# Epoch 002 | Validation loss: 0.4371
# Epoch 002 completed in 10.16s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.4371)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8322, AUC-PR: 0.6328, Accuracy: 0.7989, B_ACC : 0.689, MCC: 0.4376, Sensitivity/Recall: 0.4545, Specificity: 0.9235, Precision: 0.6827, F1-score: 0.5457, CK-score 0.4232
# Test Performance:
#   ROC-AUC: 0.8322 | PR-AUC: 0.6328 | Accuracy: 0.7989
#   F1: 0.5457 | MCC: 0.4376 | Balanced Acc: 0.6890
# ------------------------------------------------------------
# Epoch 003 | Training loss: 0.4508
# Epoch 003 | Validation loss: 0.4293
# Epoch 003 completed in 10.51s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.4293)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.836, AUC-PR: 0.6389, Accuracy: 0.8017, B_ACC : 0.7072, MCC: 0.4566, Sensitivity/Recall: 0.5053, Specificity: 0.909, Precision: 0.6678, F1-score: 0.5753, CK-score 0.4492
# Test Performance:
#   ROC-AUC: 0.8360 | PR-AUC: 0.6389 | Accuracy: 0.8017
#   F1: 0.5753 | MCC: 0.4566 | Balanced Acc: 0.7072
# ------------------------------------------------------------
# Epoch 004 | Training loss: 0.4409
# Epoch 004 | Validation loss: 0.4258
# Epoch 004 completed in 10.09s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.4258)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8395, AUC-PR: 0.6439, Accuracy: 0.8024, B_ACC : 0.7153, MCC: 0.4645, Sensitivity/Recall: 0.5294, Specificity: 0.9013, Precision: 0.66, F1-score: 0.5875, CK-score 0.4597
# Test Performance:
#   ROC-AUC: 0.8395 | PR-AUC: 0.6439 | Accuracy: 0.8024
#   F1: 0.5875 | MCC: 0.4645 | Balanced Acc: 0.7153
# ------------------------------------------------------------
# Epoch 005 | Training loss: 0.4384
# Epoch 005 | Validation loss: 0.4238
# Epoch 005 completed in 10.04s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.4238)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8414, AUC-PR: 0.6495, Accuracy: 0.8088, B_ACC : 0.7299, MCC: 0.4873, Sensitivity/Recall: 0.5615, Specificity: 0.8984, Precision: 0.6667, F1-score: 0.6096, CK-score 0.4842
# Test Performance:
#   ROC-AUC: 0.8414 | PR-AUC: 0.6495 | Accuracy: 0.8088
#   F1: 0.6096 | MCC: 0.4873 | Balanced Acc: 0.7299
# ------------------------------------------------------------
# Epoch 006 | Training loss: 0.4336
# Epoch 006 | Validation loss: 0.4216
# Epoch 006 completed in 10.27s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.4216)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8439, AUC-PR: 0.6542, Accuracy: 0.8081, B_ACC : 0.7303, MCC: 0.4865, Sensitivity/Recall: 0.5642, Specificity: 0.8964, Precision: 0.6635, F1-score: 0.6098, CK-score 0.4837
# Test Performance:
#   ROC-AUC: 0.8439 | PR-AUC: 0.6542 | Accuracy: 0.8081
#   F1: 0.6098 | MCC: 0.4865 | Balanced Acc: 0.7303
# ------------------------------------------------------------
# Epoch 007 | Training loss: 0.4290
# Epoch 007 | Validation loss: 0.4198
# Epoch 007 completed in 10.12s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.4198)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8452, AUC-PR: 0.6541, Accuracy: 0.8081, B_ACC : 0.7346, MCC: 0.4901, Sensitivity/Recall: 0.5775, Specificity: 0.8916, Precision: 0.6585, F1-score: 0.6153, CK-score 0.4883
# Test Performance:
#   ROC-AUC: 0.8452 | PR-AUC: 0.6541 | Accuracy: 0.8081
#   F1: 0.6153 | MCC: 0.4901 | Balanced Acc: 0.7346
# ------------------------------------------------------------
# Epoch 008 | Training loss: 0.4269
# Epoch 008 | Validation loss: 0.4181
# Epoch 008 completed in 10.24s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.4181)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8463, AUC-PR: 0.6572, Accuracy: 0.8074, B_ACC : 0.7366, MCC: 0.4909, Sensitivity/Recall: 0.5856, Specificity: 0.8877, Precision: 0.6537, F1-score: 0.6178, CK-score 0.4896
# Test Performance:
#   ROC-AUC: 0.8463 | PR-AUC: 0.6572 | Accuracy: 0.8074
#   F1: 0.6178 | MCC: 0.4909 | Balanced Acc: 0.7366
# ------------------------------------------------------------
# Epoch 009 | Training loss: 0.4278
# Epoch 009 | Validation loss: 0.4163
# Epoch 009 completed in 10.33s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.4163)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8471, AUC-PR: 0.6591, Accuracy: 0.8053, B_ACC : 0.7318, MCC: 0.4833, Sensitivity/Recall: 0.5749, Specificity: 0.8887, Precision: 0.6515, F1-score: 0.6108, CK-score 0.4816
# Test Performance:
#   ROC-AUC: 0.8471 | PR-AUC: 0.6591 | Accuracy: 0.8053
#   F1: 0.6108 | MCC: 0.4833 | Balanced Acc: 0.7318
# ------------------------------------------------------------
# Epoch 010 | Training loss: 0.4258
# Epoch 010 | Validation loss: 0.4154
# Epoch 010 completed in 10.44s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.4154)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8478, AUC-PR: 0.6607, Accuracy: 0.8045, B_ACC : 0.733, MCC: 0.4833, Sensitivity/Recall: 0.5802, Specificity: 0.8858, Precision: 0.6478, F1-score: 0.6121, CK-score 0.482
# Test Performance:
#   ROC-AUC: 0.8478 | PR-AUC: 0.6607 | Accuracy: 0.8045
#   F1: 0.6121 | MCC: 0.4833 | Balanced Acc: 0.7330
# ------------------------------------------------------------
# Epoch 011 | Training loss: 0.4238
# Epoch 011 | Validation loss: 0.4153
# Epoch 011 completed in 10.15s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.4153)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.848, AUC-PR: 0.6616, Accuracy: 0.8031, B_ACC : 0.7329, MCC: 0.4811, Sensitivity/Recall: 0.5829, Specificity: 0.8829, Precision: 0.6431, F1-score: 0.6115, CK-score 0.4801
# Test Performance:
#   ROC-AUC: 0.8480 | PR-AUC: 0.6616 | Accuracy: 0.8031
#   F1: 0.6115 | MCC: 0.4811 | Balanced Acc: 0.7329
# ------------------------------------------------------------
# Epoch 012 | Training loss: 0.4244
# Epoch 012 | Validation loss: 0.4144
# Epoch 012 completed in 10.09s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.4144)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8484, AUC-PR: 0.6604, Accuracy: 0.801, B_ACC : 0.7323, MCC: 0.4775, Sensitivity/Recall: 0.5856, Specificity: 0.879, Precision: 0.6366, F1-score: 0.61, CK-score 0.4768
# Test Performance:
#   ROC-AUC: 0.8484 | PR-AUC: 0.6604 | Accuracy: 0.8010
#   F1: 0.6100 | MCC: 0.4775 | Balanced Acc: 0.7323
# ------------------------------------------------------------
# Epoch 013 | Training loss: 0.4233
# Epoch 013 | Validation loss: 0.4137
# Epoch 013 completed in 10.32s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.4137)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.849, AUC-PR: 0.6616, Accuracy: 0.8017, B_ACC : 0.7336, MCC: 0.4798, Sensitivity/Recall: 0.5882, Specificity: 0.879, Precision: 0.6377, F1-score: 0.612, CK-score 0.4791
# Test Performance:
#   ROC-AUC: 0.8490 | PR-AUC: 0.6616 | Accuracy: 0.8017
#   F1: 0.6120 | MCC: 0.4798 | Balanced Acc: 0.7336
# ------------------------------------------------------------
# Epoch 014 | Training loss: 0.4227
# Epoch 014 | Validation loss: 0.4130
# Epoch 014 completed in 10.32s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.4130)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8495, AUC-PR: 0.6631, Accuracy: 0.8017, B_ACC : 0.7328, MCC: 0.479, Sensitivity/Recall: 0.5856, Specificity: 0.88, Precision: 0.6385, F1-score: 0.6109, CK-score 0.4782
# Test Performance:
#   ROC-AUC: 0.8495 | PR-AUC: 0.6631 | Accuracy: 0.8017
#   F1: 0.6109 | MCC: 0.4790 | Balanced Acc: 0.7328
# ------------------------------------------------------------
# Epoch 015 | Training loss: 0.4212
# Epoch 015 | Validation loss: 0.4121
# Epoch 015 completed in 10.29s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.4121)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8494, AUC-PR: 0.662, Accuracy: 0.8031, B_ACC : 0.7312, MCC: 0.4795, Sensitivity/Recall: 0.5775, Specificity: 0.8848, Precision: 0.6448, F1-score: 0.6093, CK-score 0.4782
# Test Performance:
#   ROC-AUC: 0.8494 | PR-AUC: 0.6620 | Accuracy: 0.8031
#   F1: 0.6093 | MCC: 0.4795 | Balanced Acc: 0.7312
# ------------------------------------------------------------
# Epoch 016 | Training loss: 0.4226
# Epoch 016 | Validation loss: 0.4113
# Epoch 016 completed in 10.38s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.4113)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.85, AUC-PR: 0.664, Accuracy: 0.8031, B_ACC : 0.7303, MCC: 0.4788, Sensitivity/Recall: 0.5749, Specificity: 0.8858, Precision: 0.6456, F1-score: 0.6082, CK-score 0.4773
# Test Performance:
#   ROC-AUC: 0.8500 | PR-AUC: 0.6640 | Accuracy: 0.8031
#   F1: 0.6082 | MCC: 0.4788 | Balanced Acc: 0.7303
# ------------------------------------------------------------
# Epoch 017 | Training loss: 0.4201
# Epoch 017 | Validation loss: 0.4109
# Epoch 017 completed in 10.26s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.4109)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8508, AUC-PR: 0.6652, Accuracy: 0.8031, B_ACC : 0.7312, MCC: 0.4795, Sensitivity/Recall: 0.5775, Specificity: 0.8848, Precision: 0.6448, F1-score: 0.6093, CK-score 0.4782
# Test Performance:
#   ROC-AUC: 0.8508 | PR-AUC: 0.6652 | Accuracy: 0.8031
#   F1: 0.6093 | MCC: 0.4795 | Balanced Acc: 0.7312
# ------------------------------------------------------------
# Epoch 018 | Training loss: 0.4185
# Epoch 018 | Validation loss: 0.4099
# Epoch 018 completed in 10.10s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.4099)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8513, AUC-PR: 0.6654, Accuracy: 0.8038, B_ACC : 0.7308, MCC: 0.4803, Sensitivity/Recall: 0.5749, Specificity: 0.8867, Precision: 0.6476, F1-score: 0.6091, CK-score 0.4788
# Test Performance:
#   ROC-AUC: 0.8513 | PR-AUC: 0.6654 | Accuracy: 0.8038
#   F1: 0.6091 | MCC: 0.4803 | Balanced Acc: 0.7308
# ------------------------------------------------------------
# Epoch 019 | Training loss: 0.4178
# Epoch 019 | Validation loss: 0.4104
# Epoch 019 completed in 10.01s
# ------------------------------------------------------------
# Epoch 020 | Training loss: 0.4192
# Epoch 020 | Validation loss: 0.4097
# Epoch 020 completed in 10.14s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.4097)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8523, AUC-PR: 0.6693, Accuracy: 0.8045, B_ACC : 0.7407, MCC: 0.4905, Sensitivity/Recall: 0.6043, Specificity: 0.8771, Precision: 0.6402, F1-score: 0.6217, CK-score 0.4901
# Test Performance:
#   ROC-AUC: 0.8523 | PR-AUC: 0.6693 | Accuracy: 0.8045
#   F1: 0.6217 | MCC: 0.4905 | Balanced Acc: 0.7407
# ------------------------------------------------------------
# Epoch 021 | Training loss: 0.4194
# Epoch 021 | Validation loss: 0.4094
# Epoch 021 completed in 10.30s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.4094)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8521, AUC-PR: 0.6716, Accuracy: 0.801, B_ACC : 0.734, MCC: 0.4791, Sensitivity/Recall: 0.5909, Specificity: 0.8771, Precision: 0.6351, F1-score: 0.6122, CK-score 0.4786
# Test Performance:
#   ROC-AUC: 0.8521 | PR-AUC: 0.6716 | Accuracy: 0.8010
#   F1: 0.6122 | MCC: 0.4791 | Balanced Acc: 0.7340
# ------------------------------------------------------------
# Epoch 022 | Training loss: 0.4170
# Epoch 022 | Validation loss: 0.4089
# Epoch 022 completed in 10.22s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.4089)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8521, AUC-PR: 0.6702, Accuracy: 0.8024, B_ACC : 0.7315, MCC: 0.4788, Sensitivity/Recall: 0.5802, Specificity: 0.8829, Precision: 0.642, F1-score: 0.6095, CK-score 0.4777
# Test Performance:
#   ROC-AUC: 0.8521 | PR-AUC: 0.6702 | Accuracy: 0.8024
#   F1: 0.6095 | MCC: 0.4788 | Balanced Acc: 0.7315
# ------------------------------------------------------------
# Epoch 023 | Training loss: 0.4132
# Epoch 023 | Validation loss: 0.4090
# Epoch 023 completed in 10.19s
# ------------------------------------------------------------
# Epoch 024 | Training loss: 0.4181
# Epoch 024 | Validation loss: 0.4092
# Epoch 024 completed in 9.93s
# ------------------------------------------------------------
# Epoch 025 | Training loss: 0.4148
# Epoch 025 | Validation loss: 0.4092
# Epoch 025 completed in 10.04s
# ------------------------------------------------------------
# Epoch 026 | Training loss: 0.4153
# Epoch 026 | Validation loss: 0.4085
# Epoch 026 completed in 10.05s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.4085)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8529, AUC-PR: 0.6732, Accuracy: 0.8024, B_ACC : 0.7332, MCC: 0.4804, Sensitivity/Recall: 0.5856, Specificity: 0.8809, Precision: 0.6404, F1-score: 0.6118, CK-score 0.4796
# Test Performance:
#   ROC-AUC: 0.8529 | PR-AUC: 0.6732 | Accuracy: 0.8024
#   F1: 0.6118 | MCC: 0.4804 | Balanced Acc: 0.7332
# ------------------------------------------------------------
# Epoch 027 | Training loss: 0.4142
# Epoch 027 | Validation loss: 0.4090
# Epoch 027 completed in 10.06s
# ------------------------------------------------------------
# Epoch 028 | Training loss: 0.4135
# Epoch 028 | Validation loss: 0.4088
# Epoch 028 completed in 9.96s
# ------------------------------------------------------------
# Epoch 029 | Training loss: 0.4149
# Epoch 029 | Validation loss: 0.4086
# Epoch 029 completed in 10.02s
# ------------------------------------------------------------
# Epoch 030 | Training loss: 0.4131
# Epoch 030 | Validation loss: 0.4083
# Epoch 030 completed in 9.89s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.4083)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8533, AUC-PR: 0.6727, Accuracy: 0.8031, B_ACC : 0.7346, MCC: 0.4827, Sensitivity/Recall: 0.5882, Specificity: 0.8809, Precision: 0.6414, F1-score: 0.6136, CK-score 0.4819
# Test Performance:
#   ROC-AUC: 0.8533 | PR-AUC: 0.6727 | Accuracy: 0.8031
#   F1: 0.6136 | MCC: 0.4827 | Balanced Acc: 0.7346
# ------------------------------------------------------------
# Epoch 031 | Training loss: 0.4136
# Epoch 031 | Validation loss: 0.4092
# Epoch 031 completed in 9.85s
# ------------------------------------------------------------
# Epoch 032 | Training loss: 0.4130
# Epoch 032 | Validation loss: 0.4081
# Epoch 032 completed in 9.87s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.4081)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8537, AUC-PR: 0.6723, Accuracy: 0.8003, B_ACC : 0.7318, MCC: 0.476, Sensitivity/Recall: 0.5856, Specificity: 0.878, Precision: 0.6348, F1-score: 0.6092, CK-score 0.4753
# Test Performance:
#   ROC-AUC: 0.8537 | PR-AUC: 0.6723 | Accuracy: 0.8003
#   F1: 0.6092 | MCC: 0.4760 | Balanced Acc: 0.7318
# ------------------------------------------------------------
# Epoch 033 | Training loss: 0.4123
# Epoch 033 | Validation loss: 0.4078
# Epoch 033 completed in 9.89s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.4078)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8535, AUC-PR: 0.6735, Accuracy: 0.8024, B_ACC : 0.735, MCC: 0.4821, Sensitivity/Recall: 0.5909, Specificity: 0.879, Precision: 0.6387, F1-score: 0.6139, CK-score 0.4814
# Test Performance:
#   ROC-AUC: 0.8535 | PR-AUC: 0.6735 | Accuracy: 0.8024
#   F1: 0.6139 | MCC: 0.4821 | Balanced Acc: 0.7350
# ------------------------------------------------------------
# Epoch 034 | Training loss: 0.4127
# Epoch 034 | Validation loss: 0.4086
# Epoch 034 completed in 10.17s
# ------------------------------------------------------------
# Epoch 035 | Training loss: 0.4103
# Epoch 035 | Validation loss: 0.4074
# Epoch 035 completed in 10.00s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.4074)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8537, AUC-PR: 0.674, Accuracy: 0.8038, B_ACC : 0.7317, MCC: 0.481, Sensitivity/Recall: 0.5775, Specificity: 0.8858, Precision: 0.6467, F1-score: 0.6101, CK-score 0.4797
# Test Performance:
#   ROC-AUC: 0.8537 | PR-AUC: 0.6740 | Accuracy: 0.8038
#   F1: 0.6101 | MCC: 0.4810 | Balanced Acc: 0.7317
# ------------------------------------------------------------
# Epoch 036 | Training loss: 0.4103
# Epoch 036 | Validation loss: 0.4083
# Epoch 036 completed in 10.16s
# ------------------------------------------------------------
# Epoch 037 | Training loss: 0.4129
# Epoch 037 | Validation loss: 0.4080
# Epoch 037 completed in 10.39s
# ------------------------------------------------------------
# Epoch 038 | Training loss: 0.4100
# Epoch 038 | Validation loss: 0.4080
# Epoch 038 completed in 10.24s
# ------------------------------------------------------------
# Epoch 039 | Training loss: 0.4091
# Epoch 039 | Validation loss: 0.4082
# Epoch 039 completed in 10.19s
# ------------------------------------------------------------
# Epoch 040 | Training loss: 0.4109
# Epoch 040 | Validation loss: 0.4078
# Epoch 040 completed in 10.35s
# ------------------------------------------------------------
# Epoch 041 | Training loss: 0.4090
# Epoch 041 | Validation loss: 0.4082
# Epoch 041 completed in 10.19s
# ------------------------------------------------------------
# Epoch 042 | Training loss: 0.4102
# Epoch 042 | Validation loss: 0.4079
# Epoch 042 completed in 10.22s
# ------------------------------------------------------------
# Epoch 043 | Training loss: 0.4090
# Epoch 043 | Validation loss: 0.4084
# Epoch 043 completed in 10.31s
# ------------------------------------------------------------
# Epoch 044 | Training loss: 0.4078
# Epoch 044 | Validation loss: 0.4087
# Epoch 044 completed in 10.23s
# ------------------------------------------------------------
# Epoch 045 | Training loss: 0.4071
# Epoch 045 | Validation loss: 0.4075
# Epoch 045 completed in 10.17s
# ------------------------------------------------------------
# Epoch 046 | Training loss: 0.4093
# Epoch 046 | Validation loss: 0.4078
# Epoch 046 completed in 10.05s
# ------------------------------------------------------------
# Epoch 047 | Training loss: 0.4066
# Epoch 047 | Validation loss: 0.4076
# Epoch 047 completed in 10.00s
# ------------------------------------------------------------
# Epoch 048 | Training loss: 0.4059
# Epoch 048 | Validation loss: 0.4078
# Epoch 048 completed in 10.22s
# ------------------------------------------------------------
# Epoch 049 | Training loss: 0.4060
# Epoch 049 | Validation loss: 0.4076
# Epoch 049 completed in 10.23s
# ------------------------------------------------------------
# Epoch 050 | Training loss: 0.4062
# Epoch 050 | Validation loss: 0.4072
# Epoch 050 completed in 10.05s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.4072)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8538, AUC-PR: 0.6715, Accuracy: 0.7996, B_ACC : 0.7279, MCC: 0.4713, Sensitivity/Recall: 0.5749, Specificity: 0.8809, Precision: 0.6361, F1-score: 0.604, CK-score 0.4702
# Test Performance:
#   ROC-AUC: 0.8538 | PR-AUC: 0.6715 | Accuracy: 0.7996
#   F1: 0.6040 | MCC: 0.4713 | Balanced Acc: 0.7279
# ------------------------------------------------------------
# Epoch 051 | Training loss: 0.4059
# Epoch 051 | Validation loss: 0.4078
# Epoch 051 completed in 10.05s
# ------------------------------------------------------------
# Epoch 052 | Training loss: 0.4069
# Epoch 052 | Validation loss: 0.4075
# Epoch 052 completed in 10.09s
# ------------------------------------------------------------
# Epoch 053 | Training loss: 0.4040
# Epoch 053 | Validation loss: 0.4081
# Epoch 053 completed in 10.06s
# ------------------------------------------------------------
# Epoch 054 | Training loss: 0.4034
# Epoch 054 | Validation loss: 0.4084
# Epoch 054 completed in 9.96s
# ------------------------------------------------------------
# Epoch 055 | Training loss: 0.4024
# Epoch 055 | Validation loss: 0.4091
# Epoch 055 completed in 10.03s
# ------------------------------------------------------------
# Epoch 056 | Training loss: 0.4059
# Epoch 056 | Validation loss: 0.4084
# Epoch 056 completed in 10.43s
# ------------------------------------------------------------
# Epoch 057 | Training loss: 0.4036
# Epoch 057 | Validation loss: 0.4083
# Epoch 057 completed in 10.28s
# ------------------------------------------------------------
# Epoch 058 | Training loss: 0.4059
# Epoch 058 | Validation loss: 0.4083
# Epoch 058 completed in 10.15s
# ------------------------------------------------------------
# Epoch 059 | Training loss: 0.4069
# Epoch 059 | Validation loss: 0.4084
# Epoch 059 completed in 10.00s
# ------------------------------------------------------------
# Epoch 060 | Training loss: 0.4010
# Epoch 060 | Validation loss: 0.4085
# Epoch 060 completed in 10.06s
# ------------------------------------------------------------
# Epoch 061 | Training loss: 0.4045
# Epoch 061 | Validation loss: 0.4082
# Epoch 061 completed in 10.17s
# ------------------------------------------------------------
# Epoch 062 | Training loss: 0.4044
# Epoch 062 | Validation loss: 0.4078
# Epoch 062 completed in 10.19s
# ------------------------------------------------------------
# Epoch 063 | Training loss: 0.4057
# Epoch 063 | Validation loss: 0.4073
# Epoch 063 completed in 10.39s
# ------------------------------------------------------------
# Epoch 064 | Training loss: 0.3999
# Epoch 064 | Validation loss: 0.4082
# Epoch 064 completed in 10.13s
# ------------------------------------------------------------
# Epoch 065 | Training loss: 0.4035
# Epoch 065 | Validation loss: 0.4077
# Epoch 065 completed in 10.01s
# ------------------------------------------------------------
# Epoch 066 | Training loss: 0.4019
# Epoch 066 | Validation loss: 0.4081
# Epoch 066 completed in 10.43s
# ------------------------------------------------------------
# Epoch 067 | Training loss: 0.4030
# Epoch 067 | Validation loss: 0.4077
# Epoch 067 completed in 10.45s
# ------------------------------------------------------------
# Epoch 068 | Training loss: 0.4032
# Epoch 068 | Validation loss: 0.4083
# Epoch 068 completed in 10.57s
# ------------------------------------------------------------
# Epoch 069 | Training loss: 0.4014
# Epoch 069 | Validation loss: 0.4086
# Epoch 069 completed in 10.52s
# ------------------------------------------------------------
# Epoch 070 | Training loss: 0.4031
# Epoch 070 | Validation loss: 0.4093
# Epoch 070 completed in 10.50s
# ------------------------------------------------------------
# Epoch 071 | Training loss: 0.4030
# Epoch 071 | Validation loss: 0.4098
# Epoch 071 completed in 10.58s
# ------------------------------------------------------------
# Epoch 072 | Training loss: 0.3982
# Epoch 072 | Validation loss: 0.4099
# Epoch 072 completed in 10.60s
# ------------------------------------------------------------
# Epoch 073 | Training loss: 0.3987
# Epoch 073 | Validation loss: 0.4103
# Epoch 073 completed in 10.38s
# ------------------------------------------------------------
# Epoch 074 | Training loss: 0.4007
# Epoch 074 | Validation loss: 0.4097
# Epoch 074 completed in 10.59s
# ------------------------------------------------------------
# Epoch 075 | Training loss: 0.4010
# Epoch 075 | Validation loss: 0.4096
# Epoch 075 completed in 10.50s
# ------------------------------------------------------------
# Epoch 076 | Training loss: 0.3982
# Epoch 076 | Validation loss: 0.4096
# Epoch 076 completed in 10.04s
# ------------------------------------------------------------
# Epoch 077 | Training loss: 0.3967
# Epoch 077 | Validation loss: 0.4103
# Epoch 077 completed in 10.22s
# ------------------------------------------------------------
# Epoch 078 | Training loss: 0.3966
# Epoch 078 | Validation loss: 0.4103
# Epoch 078 completed in 10.26s
# ------------------------------------------------------------
# Epoch 079 | Training loss: 0.4001
# Epoch 079 | Validation loss: 0.4101
# Epoch 079 completed in 10.24s
#
# Early stopping à l'époque 79 (patience: 29)
#
# Meilleur modèle chargé (époque 50, val_loss: 0.4072)
#
# === Évaluation finale ===
# Performance sur l'ensemble de validation:
# Performance for test_dataset
# AUC-ROC: 0.8548, AUC-PR: 0.7121, Accuracy: 0.8021, B_ACC : 0.7384, MCC: 0.4847, Sensitivity/Recall: 0.6027, Specificity: 0.8742, Precision: 0.6338, F1-score: 0.6179, CK-score 0.4845
# Val Performance:
#   ROC-AUC: 0.8548 | PR-AUC: 0.7121 | Accuracy: 0.8021
#   F1: 0.6179 | MCC: 0.4847 | Balanced Acc: 0.7384
#
# Performance sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.851, AUC-PR: 0.6701, Accuracy: 0.8003, B_ACC : 0.7301, MCC: 0.4744, Sensitivity/Recall: 0.5802, Specificity: 0.88, Precision: 0.6364, F1-score: 0.607, CK-score 0.4735
# Test Performance:
#   ROC-AUC: 0.8510 | PR-AUC: 0.6701 | Accuracy: 0.8003
#   F1: 0.6070 | MCC: 0.4744 | Balanced Acc: 0.7301
#
# === Analyse d'interprétabilité ===
#
# Top 10 features importantes:
#    1. SeniorCitizen       : 0.0557
#    2. MonthlyCharges      : 0.0556
#    3. TechSupport         : 0.0546
#    4. OnlineSecurity      : 0.0539
#    5. Dependents          : 0.0539
#    6. TotalCharges        : 0.0531
#    7. tenure              : 0.0526
#    8. OnlineBackup        : 0.0526
#    9. PhoneService        : 0.0525
#   10. DeviceProtection    : 0.0524
#
# Génération des visualisations...
# Graphique d'importance sauvegardé: results/results_telecom/ftt_plus/seed_0/heatmaps/interpretable_ftt_plus_importance_seed_0.png
# Avertissement: Impossible de générer la heatmap d'attention pour interpretable_ftt_plus: 'numpy.ndarray' object has no attribute 'cpu'
#
# === Résultats sauvegardés ===
# Métriques: results/results_telecom/ftt_plus/seed_0/interpretable_ftt_plus_metrics_seed_0.json
# Importance: results/results_telecom/ftt_plus/seed_0/interpretable_ftt_plus_importance_seed_0.json
# Visualisations: results/results_telecom/ftt_plus/seed_0/interpretable_ftt_plus_{importance|attention}_seed_0.png
# Modèle: results/results_telecom/ftt_plus/seed_0/interpretable_ftt_plus_weights_seed_0.pt
# Entraînement terminé!

# %% [markdown]
# ## Interpretable Sparse FT-T + training

# %%
import os

# Changer vers le répertoire racine
os.chdir('/kaggle/working/customer-churn-ft_transformer')

# Utiliser PYTHONPATH pour que train.py trouve les modules
# !PYTHONPATH=/kaggle/working/customer-churn-ft_transformer python train/Telecom/train_sparse_ftt_plus/train.py
# Out:
# Utilisation du device: cuda
# Seed: 0
# Données originales: 7043 lignes
# Après nettoyage: 7032 lignes (11 supprimées)
#
# Informations sur les features:
# Features numériques (3): ['tenure', 'MonthlyCharges', 'TotalCharges']
# Variables catégorielles (16): ['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod']
# Cardinalités des variables catégorielles: [2, 2, 2, 2, 2, 3, 3, 3, 3, 3, 3, 3, 3, 3, 2, 4]
# Distribution des classes: [5163 1869]
# Tailles des ensembles:
# Train: 4781 | Val: 844 | Test: 1407
# Configuration du modèle:
#   - Features numériques: 3
#   - Features catégorielles: 16 (cardinalités: [2, 2, 2, 2, 2, 3, 3, 3, 3, 3, 3, 3, 3, 3, 2, 4])
#   - Taille des tokens: 128
# Type d'embedding numérique: T
# /usr/local/lib/python3.11/dist-packages/rtdl_num_embeddings.py:499: UserWarning: Computing tree-based bins involves the conversion of the input PyTorch tensors to NumPy arrays. The provided PyTorch tensors are not located on CPU, so the conversion has some overhead.
#   warnings.warn(
# Nombre de paramètres: 507,265
#
# === Début de l'entraînement ===
# Epoch 000 | Training loss: 0.6008
# Epoch 000 | Validation loss: 0.5083
# Epoch 000 completed in 16.99s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.5083)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8161, AUC-PR: 0.5983, Accuracy: 0.7448, B_ACC : 0.5277, MCC: 0.1619, Sensitivity/Recall: 0.0642, Specificity: 0.9913, Precision: 0.7273, F1-score: 0.118, CK-score 0.0782
# Test Performance:
#   ROC-AUC: 0.8161 | PR-AUC: 0.5983 | Accuracy: 0.7448
#   F1: 0.1180 | MCC: 0.1619 | Balanced Acc: 0.5277
# ------------------------------------------------------------
# Epoch 001 | Training loss: 0.5064
# Epoch 001 | Validation loss: 0.4655
# Epoch 001 completed in 16.43s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.4655)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8244, AUC-PR: 0.6094, Accuracy: 0.779, B_ACC : 0.6286, MCC: 0.3512, Sensitivity/Recall: 0.3075, Specificity: 0.9497, Precision: 0.6886, F1-score: 0.4251, CK-score 0.3123
# Test Performance:
#   ROC-AUC: 0.8244 | PR-AUC: 0.6094 | Accuracy: 0.7790
#   F1: 0.4251 | MCC: 0.3512 | Balanced Acc: 0.6286
# ------------------------------------------------------------
# Epoch 002 | Training loss: 0.4745
# Epoch 002 | Validation loss: 0.4480
# Epoch 002 completed in 16.40s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.4480)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8281, AUC-PR: 0.617, Accuracy: 0.8088, B_ACC : 0.7069, MCC: 0.4703, Sensitivity/Recall: 0.4893, Specificity: 0.9245, Precision: 0.7011, F1-score: 0.5764, CK-score 0.4579
# Test Performance:
#   ROC-AUC: 0.8281 | PR-AUC: 0.6170 | Accuracy: 0.8088
#   F1: 0.5764 | MCC: 0.4703 | Balanced Acc: 0.7069
# ------------------------------------------------------------
# Epoch 003 | Training loss: 0.4604
# Epoch 003 | Validation loss: 0.4420
# Epoch 003 completed in 16.40s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.4420)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8303, AUC-PR: 0.6211, Accuracy: 0.8109, B_ACC : 0.7203, MCC: 0.4836, Sensitivity/Recall: 0.5267, Specificity: 0.9138, Precision: 0.6888, F1-score: 0.5969, CK-score 0.4763
# Test Performance:
#   ROC-AUC: 0.8303 | PR-AUC: 0.6211 | Accuracy: 0.8109
#   F1: 0.5969 | MCC: 0.4836 | Balanced Acc: 0.7203
# ------------------------------------------------------------
# Epoch 004 | Training loss: 0.4528
# Epoch 004 | Validation loss: 0.4388
# Epoch 004 completed in 16.41s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.4388)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8336, AUC-PR: 0.6299, Accuracy: 0.8131, B_ACC : 0.7286, MCC: 0.4937, Sensitivity/Recall: 0.5481, Specificity: 0.909, Precision: 0.6856, F1-score: 0.6092, CK-score 0.4884
# Test Performance:
#   ROC-AUC: 0.8336 | PR-AUC: 0.6299 | Accuracy: 0.8131
#   F1: 0.6092 | MCC: 0.4937 | Balanced Acc: 0.7286
# ------------------------------------------------------------
# Epoch 005 | Training loss: 0.4453
# Epoch 005 | Validation loss: 0.4365
# Epoch 005 completed in 16.41s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.4365)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8365, AUC-PR: 0.6352, Accuracy: 0.8124, B_ACC : 0.7315, MCC: 0.4946, Sensitivity/Recall: 0.5588, Specificity: 0.9042, Precision: 0.6786, F1-score: 0.6129, CK-score 0.4906
# Test Performance:
#   ROC-AUC: 0.8365 | PR-AUC: 0.6352 | Accuracy: 0.8124
#   F1: 0.6129 | MCC: 0.4946 | Balanced Acc: 0.7315
# ------------------------------------------------------------
# Epoch 006 | Training loss: 0.4438
# Epoch 006 | Validation loss: 0.4330
# Epoch 006 completed in 16.22s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.4330)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.839, AUC-PR: 0.6411, Accuracy: 0.8117, B_ACC : 0.7353, MCC: 0.4965, Sensitivity/Recall: 0.5722, Specificity: 0.8984, Precision: 0.6708, F1-score: 0.6176, CK-score 0.4937
# Test Performance:
#   ROC-AUC: 0.8390 | PR-AUC: 0.6411 | Accuracy: 0.8117
#   F1: 0.6176 | MCC: 0.4965 | Balanced Acc: 0.7353
# ------------------------------------------------------------
# Epoch 007 | Training loss: 0.4428
# Epoch 007 | Validation loss: 0.4294
# Epoch 007 completed in 16.31s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.4294)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8413, AUC-PR: 0.6459, Accuracy: 0.8109, B_ACC : 0.7348, MCC: 0.4949, Sensitivity/Recall: 0.5722, Specificity: 0.8974, Precision: 0.6688, F1-score: 0.6167, CK-score 0.4922
# Test Performance:
#   ROC-AUC: 0.8413 | PR-AUC: 0.6459 | Accuracy: 0.8109
#   F1: 0.6167 | MCC: 0.4949 | Balanced Acc: 0.7348
# ------------------------------------------------------------
# Epoch 008 | Training loss: 0.4374
# Epoch 008 | Validation loss: 0.4278
# Epoch 008 completed in 16.24s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.4278)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8423, AUC-PR: 0.6475, Accuracy: 0.8109, B_ACC : 0.7356, MCC: 0.4956, Sensitivity/Recall: 0.5749, Specificity: 0.8964, Precision: 0.6677, F1-score: 0.6178, CK-score 0.4932
# Test Performance:
#   ROC-AUC: 0.8423 | PR-AUC: 0.6475 | Accuracy: 0.8109
#   F1: 0.6178 | MCC: 0.4956 | Balanced Acc: 0.7356
# ------------------------------------------------------------
# Epoch 009 | Training loss: 0.4352
# Epoch 009 | Validation loss: 0.4246
# Epoch 009 completed in 16.33s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.4246)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8432, AUC-PR: 0.6502, Accuracy: 0.8117, B_ACC : 0.7361, MCC: 0.4972, Sensitivity/Recall: 0.5749, Specificity: 0.8974, Precision: 0.6698, F1-score: 0.6187, CK-score 0.4946
# Test Performance:
#   ROC-AUC: 0.8432 | PR-AUC: 0.6502 | Accuracy: 0.8117
#   F1: 0.6187 | MCC: 0.4972 | Balanced Acc: 0.7361
# ------------------------------------------------------------
# Epoch 010 | Training loss: 0.4351
# Epoch 010 | Validation loss: 0.4226
# Epoch 010 completed in 16.38s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.4226)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8441, AUC-PR: 0.6534, Accuracy: 0.8124, B_ACC : 0.74, MCC: 0.5016, Sensitivity/Recall: 0.5856, Specificity: 0.8945, Precision: 0.6677, F1-score: 0.624, CK-score 0.4996
# Test Performance:
#   ROC-AUC: 0.8441 | PR-AUC: 0.6534 | Accuracy: 0.8124
#   F1: 0.6240 | MCC: 0.5016 | Balanced Acc: 0.7400
# ------------------------------------------------------------
# Epoch 011 | Training loss: 0.4305
# Epoch 011 | Validation loss: 0.4208
# Epoch 011 completed in 16.72s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.4208)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8451, AUC-PR: 0.6563, Accuracy: 0.8095, B_ACC : 0.7364, MCC: 0.4939, Sensitivity/Recall: 0.5802, Specificity: 0.8925, Precision: 0.6616, F1-score: 0.6182, CK-score 0.4921
# Test Performance:
#   ROC-AUC: 0.8451 | PR-AUC: 0.6563 | Accuracy: 0.8095
#   F1: 0.6182 | MCC: 0.4939 | Balanced Acc: 0.7364
# ------------------------------------------------------------
# Epoch 012 | Training loss: 0.4312
# Epoch 012 | Validation loss: 0.4190
# Epoch 012 completed in 16.47s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.4190)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8454, AUC-PR: 0.6581, Accuracy: 0.8095, B_ACC : 0.7381, MCC: 0.4954, Sensitivity/Recall: 0.5856, Specificity: 0.8906, Precision: 0.6596, F1-score: 0.6204, CK-score 0.4939
# Test Performance:
#   ROC-AUC: 0.8454 | PR-AUC: 0.6581 | Accuracy: 0.8095
#   F1: 0.6204 | MCC: 0.4954 | Balanced Acc: 0.7381
# ------------------------------------------------------------
# Epoch 013 | Training loss: 0.4305
# Epoch 013 | Validation loss: 0.4176
# Epoch 013 completed in 16.78s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.4176)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8459, AUC-PR: 0.6575, Accuracy: 0.8131, B_ACC : 0.7465, MCC: 0.5082, Sensitivity/Recall: 0.6043, Specificity: 0.8887, Precision: 0.6628, F1-score: 0.6322, CK-score 0.5072
# Test Performance:
#   ROC-AUC: 0.8459 | PR-AUC: 0.6575 | Accuracy: 0.8131
#   F1: 0.6322 | MCC: 0.5082 | Balanced Acc: 0.7465
# ------------------------------------------------------------
# Epoch 014 | Training loss: 0.4316
# Epoch 014 | Validation loss: 0.4157
# Epoch 014 completed in 16.52s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.4157)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8468, AUC-PR: 0.6604, Accuracy: 0.8088, B_ACC : 0.7342, MCC: 0.4909, Sensitivity/Recall: 0.5749, Specificity: 0.8935, Precision: 0.6615, F1-score: 0.6152, CK-score 0.4888
# Test Performance:
#   ROC-AUC: 0.8468 | PR-AUC: 0.6604 | Accuracy: 0.8088
#   F1: 0.6152 | MCC: 0.4909 | Balanced Acc: 0.7342
# ------------------------------------------------------------
# Epoch 015 | Training loss: 0.4275
# Epoch 015 | Validation loss: 0.4150
# Epoch 015 completed in 16.68s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.4150)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8475, AUC-PR: 0.6625, Accuracy: 0.8095, B_ACC : 0.7364, MCC: 0.4939, Sensitivity/Recall: 0.5802, Specificity: 0.8925, Precision: 0.6616, F1-score: 0.6182, CK-score 0.4921
# Test Performance:
#   ROC-AUC: 0.8475 | PR-AUC: 0.6625 | Accuracy: 0.8095
#   F1: 0.6182 | MCC: 0.4939 | Balanced Acc: 0.7364
# ------------------------------------------------------------
# Epoch 016 | Training loss: 0.4247
# Epoch 016 | Validation loss: 0.4138
# Epoch 016 completed in 16.59s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.4138)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8477, AUC-PR: 0.6634, Accuracy: 0.8074, B_ACC : 0.7341, MCC: 0.4886, Sensitivity/Recall: 0.5775, Specificity: 0.8906, Precision: 0.6565, F1-score: 0.6145, CK-score 0.4868
# Test Performance:
#   ROC-AUC: 0.8477 | PR-AUC: 0.6634 | Accuracy: 0.8074
#   F1: 0.6145 | MCC: 0.4886 | Balanced Acc: 0.7341
# ------------------------------------------------------------
# Epoch 017 | Training loss: 0.4231
# Epoch 017 | Validation loss: 0.4134
# Epoch 017 completed in 16.53s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.4134)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8481, AUC-PR: 0.6636, Accuracy: 0.8081, B_ACC : 0.732, MCC: 0.4879, Sensitivity/Recall: 0.5695, Specificity: 0.8945, Precision: 0.6615, F1-score: 0.6121, CK-score 0.4855
# Test Performance:
#   ROC-AUC: 0.8481 | PR-AUC: 0.6636 | Accuracy: 0.8081
#   F1: 0.6121 | MCC: 0.4879 | Balanced Acc: 0.7320
# ------------------------------------------------------------
# Epoch 018 | Training loss: 0.4231
# Epoch 018 | Validation loss: 0.4125
# Epoch 018 completed in 16.58s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.4125)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8482, AUC-PR: 0.6643, Accuracy: 0.8045, B_ACC : 0.7304, MCC: 0.481, Sensitivity/Recall: 0.5722, Specificity: 0.8887, Precision: 0.6505, F1-score: 0.6088, CK-score 0.4793
# Test Performance:
#   ROC-AUC: 0.8482 | PR-AUC: 0.6643 | Accuracy: 0.8045
#   F1: 0.6088 | MCC: 0.4810 | Balanced Acc: 0.7304
# ------------------------------------------------------------
# Epoch 019 | Training loss: 0.4216
# Epoch 019 | Validation loss: 0.4115
# Epoch 019 completed in 16.71s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.4115)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8486, AUC-PR: 0.6667, Accuracy: 0.8067, B_ACC : 0.7293, MCC: 0.4834, Sensitivity/Recall: 0.5642, Specificity: 0.8945, Precision: 0.6594, F1-score: 0.6081, CK-score 0.4808
# Test Performance:
#   ROC-AUC: 0.8486 | PR-AUC: 0.6667 | Accuracy: 0.8067
#   F1: 0.6081 | MCC: 0.4834 | Balanced Acc: 0.7293
# ------------------------------------------------------------
# Epoch 020 | Training loss: 0.4229
# Epoch 020 | Validation loss: 0.4104
# Epoch 020 completed in 16.47s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.4104)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8487, AUC-PR: 0.6667, Accuracy: 0.8074, B_ACC : 0.7298, MCC: 0.4849, Sensitivity/Recall: 0.5642, Specificity: 0.8955, Precision: 0.6614, F1-score: 0.6089, CK-score 0.4822
# Test Performance:
#   ROC-AUC: 0.8487 | PR-AUC: 0.6667 | Accuracy: 0.8074
#   F1: 0.6089 | MCC: 0.4849 | Balanced Acc: 0.7298
# ------------------------------------------------------------
# Epoch 021 | Training loss: 0.4222
# Epoch 021 | Validation loss: 0.4097
# Epoch 021 completed in 16.56s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.4097)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8489, AUC-PR: 0.6688, Accuracy: 0.8053, B_ACC : 0.7284, MCC: 0.4803, Sensitivity/Recall: 0.5642, Specificity: 0.8925, Precision: 0.6553, F1-score: 0.6063, CK-score 0.4779
# Test Performance:
#   ROC-AUC: 0.8489 | PR-AUC: 0.6688 | Accuracy: 0.8053
#   F1: 0.6063 | MCC: 0.4803 | Balanced Acc: 0.7284
# ------------------------------------------------------------
# Epoch 022 | Training loss: 0.4200
# Epoch 022 | Validation loss: 0.4091
# Epoch 022 completed in 16.49s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.4091)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8492, AUC-PR: 0.6701, Accuracy: 0.8081, B_ACC : 0.7311, MCC: 0.4872, Sensitivity/Recall: 0.5668, Specificity: 0.8955, Precision: 0.6625, F1-score: 0.6109, CK-score 0.4846
# Test Performance:
#   ROC-AUC: 0.8492 | PR-AUC: 0.6701 | Accuracy: 0.8081
#   F1: 0.6109 | MCC: 0.4872 | Balanced Acc: 0.7311
# ------------------------------------------------------------
# Epoch 023 | Training loss: 0.4207
# Epoch 023 | Validation loss: 0.4090
# Epoch 023 completed in 16.69s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.4090)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8496, AUC-PR: 0.6714, Accuracy: 0.8067, B_ACC : 0.7293, MCC: 0.4834, Sensitivity/Recall: 0.5642, Specificity: 0.8945, Precision: 0.6594, F1-score: 0.6081, CK-score 0.4808
# Test Performance:
#   ROC-AUC: 0.8496 | PR-AUC: 0.6714 | Accuracy: 0.8067
#   F1: 0.6081 | MCC: 0.4834 | Balanced Acc: 0.7293
# ------------------------------------------------------------
# Epoch 024 | Training loss: 0.4177
# Epoch 024 | Validation loss: 0.4100
# Epoch 024 completed in 16.48s
# ------------------------------------------------------------
# Epoch 025 | Training loss: 0.4176
# Epoch 025 | Validation loss: 0.4089
# Epoch 025 completed in 16.46s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.4089)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8497, AUC-PR: 0.6713, Accuracy: 0.8067, B_ACC : 0.7285, MCC: 0.4826, Sensitivity/Recall: 0.5615, Specificity: 0.8955, Precision: 0.6604, F1-score: 0.6069, CK-score 0.4799
# Test Performance:
#   ROC-AUC: 0.8497 | PR-AUC: 0.6713 | Accuracy: 0.8067
#   F1: 0.6069 | MCC: 0.4826 | Balanced Acc: 0.7285
# ------------------------------------------------------------
# Epoch 026 | Training loss: 0.4184
# Epoch 026 | Validation loss: 0.4082
# Epoch 026 completed in 16.37s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.4082)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8505, AUC-PR: 0.6723, Accuracy: 0.806, B_ACC : 0.7271, MCC: 0.4804, Sensitivity/Recall: 0.5588, Specificity: 0.8955, Precision: 0.6593, F1-score: 0.6049, CK-score 0.4775
# Test Performance:
#   ROC-AUC: 0.8505 | PR-AUC: 0.6723 | Accuracy: 0.8060
#   F1: 0.6049 | MCC: 0.4804 | Balanced Acc: 0.7271
# ------------------------------------------------------------
# Epoch 027 | Training loss: 0.4192
# Epoch 027 | Validation loss: 0.4086
# Epoch 027 completed in 16.58s
# ------------------------------------------------------------
# Epoch 028 | Training loss: 0.4164
# Epoch 028 | Validation loss: 0.4089
# Epoch 028 completed in 16.51s
# ------------------------------------------------------------
# Epoch 029 | Training loss: 0.4170
# Epoch 029 | Validation loss: 0.4088
# Epoch 029 completed in 16.57s
# ------------------------------------------------------------
# Epoch 030 | Training loss: 0.4184
# Epoch 030 | Validation loss: 0.4081
# Epoch 030 completed in 16.50s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.4081)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8508, AUC-PR: 0.673, Accuracy: 0.8081, B_ACC : 0.7346, MCC: 0.4901, Sensitivity/Recall: 0.5775, Specificity: 0.8916, Precision: 0.6585, F1-score: 0.6153, CK-score 0.4883
# Test Performance:
#   ROC-AUC: 0.8508 | PR-AUC: 0.6730 | Accuracy: 0.8081
#   F1: 0.6153 | MCC: 0.4901 | Balanced Acc: 0.7346
# ------------------------------------------------------------
# Epoch 031 | Training loss: 0.4142
# Epoch 031 | Validation loss: 0.4085
# Epoch 031 completed in 16.43s
# ------------------------------------------------------------
# Epoch 032 | Training loss: 0.4173
# Epoch 032 | Validation loss: 0.4084
# Epoch 032 completed in 16.50s
# ------------------------------------------------------------
# Epoch 033 | Training loss: 0.4179
# Epoch 033 | Validation loss: 0.4083
# Epoch 033 completed in 16.35s
# ------------------------------------------------------------
# Epoch 034 | Training loss: 0.4148
# Epoch 034 | Validation loss: 0.4082
# Epoch 034 completed in 16.51s
# ------------------------------------------------------------
# Epoch 035 | Training loss: 0.4155
# Epoch 035 | Validation loss: 0.4086
# Epoch 035 completed in 16.38s
# ------------------------------------------------------------
# Epoch 036 | Training loss: 0.4160
# Epoch 036 | Validation loss: 0.4076
# Epoch 036 completed in 16.52s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.4076)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8514, AUC-PR: 0.6747, Accuracy: 0.8095, B_ACC : 0.7381, MCC: 0.4954, Sensitivity/Recall: 0.5856, Specificity: 0.8906, Precision: 0.6596, F1-score: 0.6204, CK-score 0.4939
# Test Performance:
#   ROC-AUC: 0.8514 | PR-AUC: 0.6747 | Accuracy: 0.8095
#   F1: 0.6204 | MCC: 0.4954 | Balanced Acc: 0.7381
# ------------------------------------------------------------
# Epoch 037 | Training loss: 0.4135
# Epoch 037 | Validation loss: 0.4065
# Epoch 037 completed in 16.39s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.4065)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8514, AUC-PR: 0.6749, Accuracy: 0.8088, B_ACC : 0.7367, MCC: 0.4932, Sensitivity/Recall: 0.5829, Specificity: 0.8906, Precision: 0.6586, F1-score: 0.6184, CK-score 0.4915
# Test Performance:
#   ROC-AUC: 0.8514 | PR-AUC: 0.6749 | Accuracy: 0.8088
#   F1: 0.6184 | MCC: 0.4932 | Balanced Acc: 0.7367
# ------------------------------------------------------------
# Epoch 038 | Training loss: 0.4156
# Epoch 038 | Validation loss: 0.4069
# Epoch 038 completed in 16.39s
# ------------------------------------------------------------
# Epoch 039 | Training loss: 0.4157
# Epoch 039 | Validation loss: 0.4072
# Epoch 039 completed in 16.46s
# ------------------------------------------------------------
# Epoch 040 | Training loss: 0.4141
# Epoch 040 | Validation loss: 0.4070
# Epoch 040 completed in 16.40s
# ------------------------------------------------------------
# Epoch 041 | Training loss: 0.4153
# Epoch 041 | Validation loss: 0.4064
# Epoch 041 completed in 16.40s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.4064)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8524, AUC-PR: 0.6762, Accuracy: 0.8102, B_ACC : 0.7352, MCC: 0.494, Sensitivity/Recall: 0.5749, Specificity: 0.8955, Precision: 0.6656, F1-score: 0.6169, CK-score 0.4917
# Test Performance:
#   ROC-AUC: 0.8524 | PR-AUC: 0.6762 | Accuracy: 0.8102
#   F1: 0.6169 | MCC: 0.4940 | Balanced Acc: 0.7352
# ------------------------------------------------------------
# Epoch 042 | Training loss: 0.4131
# Epoch 042 | Validation loss: 0.4072
# Epoch 042 completed in 16.55s
# ------------------------------------------------------------
# Epoch 043 | Training loss: 0.4121
# Epoch 043 | Validation loss: 0.4072
# Epoch 043 completed in 16.58s
# ------------------------------------------------------------
# Epoch 044 | Training loss: 0.4144
# Epoch 044 | Validation loss: 0.4069
# Epoch 044 completed in 16.63s
# ------------------------------------------------------------
# Epoch 045 | Training loss: 0.4111
# Epoch 045 | Validation loss: 0.4066
# Epoch 045 completed in 17.00s
# ------------------------------------------------------------
# Epoch 046 | Training loss: 0.4117
# Epoch 046 | Validation loss: 0.4067
# Epoch 046 completed in 16.67s
# ------------------------------------------------------------
# Epoch 047 | Training loss: 0.4127
# Epoch 047 | Validation loss: 0.4067
# Epoch 047 completed in 16.57s
# ------------------------------------------------------------
# Epoch 048 | Training loss: 0.4114
# Epoch 048 | Validation loss: 0.4064
# Epoch 048 completed in 16.61s
# ------------------------------------------------------------
# Epoch 049 | Training loss: 0.4108
# Epoch 049 | Validation loss: 0.4064
# Epoch 049 completed in 16.44s
# ------------------------------------------------------------
# Epoch 050 | Training loss: 0.4109
# Epoch 050 | Validation loss: 0.4074
# Epoch 050 completed in 16.59s
# ------------------------------------------------------------
# Epoch 051 | Training loss: 0.4124
# Epoch 051 | Validation loss: 0.4068
# Epoch 051 completed in 16.44s
# ------------------------------------------------------------
# Epoch 052 | Training loss: 0.4121
# Epoch 052 | Validation loss: 0.4067
# Epoch 052 completed in 16.38s
# ------------------------------------------------------------
# Epoch 053 | Training loss: 0.4112
# Epoch 053 | Validation loss: 0.4070
# Epoch 053 completed in 16.49s
# ------------------------------------------------------------
# Epoch 054 | Training loss: 0.4094
# Epoch 054 | Validation loss: 0.4076
# Epoch 054 completed in 16.64s
# ------------------------------------------------------------
# Epoch 055 | Training loss: 0.4118
# Epoch 055 | Validation loss: 0.4076
# Epoch 055 completed in 16.32s
# ------------------------------------------------------------
# Epoch 056 | Training loss: 0.4119
# Epoch 056 | Validation loss: 0.4070
# Epoch 056 completed in 16.19s
# ------------------------------------------------------------
# Epoch 057 | Training loss: 0.4091
# Epoch 057 | Validation loss: 0.4075
# Epoch 057 completed in 16.36s
# ------------------------------------------------------------
# Epoch 058 | Training loss: 0.4094
# Epoch 058 | Validation loss: 0.4070
# Epoch 058 completed in 16.58s
# ------------------------------------------------------------
# Epoch 059 | Training loss: 0.4116
# Epoch 059 | Validation loss: 0.4063
# Epoch 059 completed in 16.62s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.4063)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8534, AUC-PR: 0.6775, Accuracy: 0.8102, B_ACC : 0.7377, MCC: 0.4962, Sensitivity/Recall: 0.5829, Specificity: 0.8925, Precision: 0.6626, F1-score: 0.6202, CK-score 0.4944
# Test Performance:
#   ROC-AUC: 0.8534 | PR-AUC: 0.6775 | Accuracy: 0.8102
#   F1: 0.6202 | MCC: 0.4962 | Balanced Acc: 0.7377
# ------------------------------------------------------------
# Epoch 060 | Training loss: 0.4095
# Epoch 060 | Validation loss: 0.4071
# Epoch 060 completed in 16.46s
# ------------------------------------------------------------
# Epoch 061 | Training loss: 0.4106
# Epoch 061 | Validation loss: 0.4069
# Epoch 061 completed in 16.63s
# ------------------------------------------------------------
# Epoch 062 | Training loss: 0.4108
# Epoch 062 | Validation loss: 0.4072
# Epoch 062 completed in 16.58s
# ------------------------------------------------------------
# Epoch 063 | Training loss: 0.4108
# Epoch 063 | Validation loss: 0.4072
# Epoch 063 completed in 16.50s
# ------------------------------------------------------------
# Epoch 064 | Training loss: 0.4072
# Epoch 064 | Validation loss: 0.4068
# Epoch 064 completed in 16.73s
# ------------------------------------------------------------
# Epoch 065 | Training loss: 0.4080
# Epoch 065 | Validation loss: 0.4068
# Epoch 065 completed in 16.59s
# ------------------------------------------------------------
# Epoch 066 | Training loss: 0.4114
# Epoch 066 | Validation loss: 0.4053
# Epoch 066 completed in 16.31s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.4053)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8535, AUC-PR: 0.6789, Accuracy: 0.8074, B_ACC : 0.7349, MCC: 0.4894, Sensitivity/Recall: 0.5802, Specificity: 0.8896, Precision: 0.6556, F1-score: 0.6156, CK-score 0.4877
# Test Performance:
#   ROC-AUC: 0.8535 | PR-AUC: 0.6789 | Accuracy: 0.8074
#   F1: 0.6156 | MCC: 0.4894 | Balanced Acc: 0.7349
# ------------------------------------------------------------
# Epoch 067 | Training loss: 0.4070
# Epoch 067 | Validation loss: 0.4055
# Epoch 067 completed in 16.58s
# ------------------------------------------------------------
# Epoch 068 | Training loss: 0.4077
# Epoch 068 | Validation loss: 0.4056
# Epoch 068 completed in 16.55s
# ------------------------------------------------------------
# Epoch 069 | Training loss: 0.4093
# Epoch 069 | Validation loss: 0.4060
# Epoch 069 completed in 16.51s
# ------------------------------------------------------------
# Epoch 070 | Training loss: 0.4066
# Epoch 070 | Validation loss: 0.4064
# Epoch 070 completed in 16.42s
# ------------------------------------------------------------
# Epoch 071 | Training loss: 0.4060
# Epoch 071 | Validation loss: 0.4071
# Epoch 071 completed in 16.40s
# ------------------------------------------------------------
# Epoch 072 | Training loss: 0.4086
# Epoch 072 | Validation loss: 0.4068
# Epoch 072 completed in 16.53s
# ------------------------------------------------------------
# Epoch 073 | Training loss: 0.4084
# Epoch 073 | Validation loss: 0.4059
# Epoch 073 completed in 16.68s
# ------------------------------------------------------------
# Epoch 074 | Training loss: 0.4065
# Epoch 074 | Validation loss: 0.4066
# Epoch 074 completed in 16.74s
# ------------------------------------------------------------
# Epoch 075 | Training loss: 0.4077
# Epoch 075 | Validation loss: 0.4059
# Epoch 075 completed in 16.70s
# ------------------------------------------------------------
# Epoch 076 | Training loss: 0.4070
# Epoch 076 | Validation loss: 0.4058
# Epoch 076 completed in 16.70s
# ------------------------------------------------------------
# Epoch 077 | Training loss: 0.4068
# Epoch 077 | Validation loss: 0.4053
# Epoch 077 completed in 16.93s
#  <<< NOUVEAU MEILLEUR MODÈLE (val_loss: 0.4053)
#  >>> Évaluation sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.8532, AUC-PR: 0.6786, Accuracy: 0.8088, B_ACC : 0.735, MCC: 0.4917, Sensitivity/Recall: 0.5775, Specificity: 0.8925, Precision: 0.6606, F1-score: 0.6163, CK-score 0.4897
# Test Performance:
#   ROC-AUC: 0.8532 | PR-AUC: 0.6786 | Accuracy: 0.8088
#   F1: 0.6163 | MCC: 0.4917 | Balanced Acc: 0.7350
# ------------------------------------------------------------
# Epoch 078 | Training loss: 0.4069
# Epoch 078 | Validation loss: 0.4059
# Epoch 078 completed in 16.89s
# ------------------------------------------------------------
# Epoch 079 | Training loss: 0.4026
# Epoch 079 | Validation loss: 0.4060
# Epoch 079 completed in 16.84s
# ------------------------------------------------------------
# Epoch 080 | Training loss: 0.4039
# Epoch 080 | Validation loss: 0.4070
# Epoch 080 completed in 16.61s
# ------------------------------------------------------------
# Epoch 081 | Training loss: 0.4051
# Epoch 081 | Validation loss: 0.4074
# Epoch 081 completed in 16.47s
# ------------------------------------------------------------
# Epoch 082 | Training loss: 0.4039
# Epoch 082 | Validation loss: 0.4078
# Epoch 082 completed in 16.60s
# ------------------------------------------------------------
# Epoch 083 | Training loss: 0.4047
# Epoch 083 | Validation loss: 0.4092
# Epoch 083 completed in 16.56s
# ------------------------------------------------------------
# Epoch 084 | Training loss: 0.4060
# Epoch 084 | Validation loss: 0.4083
# Epoch 084 completed in 16.61s
# ------------------------------------------------------------
# Epoch 085 | Training loss: 0.4051
# Epoch 085 | Validation loss: 0.4088
# Epoch 085 completed in 16.60s
# ------------------------------------------------------------
# Epoch 086 | Training loss: 0.4025
# Epoch 086 | Validation loss: 0.4079
# Epoch 086 completed in 16.67s
# ------------------------------------------------------------
# Epoch 087 | Training loss: 0.4041
# Epoch 087 | Validation loss: 0.4079
# Epoch 087 completed in 16.66s
# ------------------------------------------------------------
# Epoch 088 | Training loss: 0.4039
# Epoch 088 | Validation loss: 0.4077
# Epoch 088 completed in 16.70s
# ------------------------------------------------------------
# Epoch 089 | Training loss: 0.4041
# Epoch 089 | Validation loss: 0.4083
# Epoch 089 completed in 16.54s
# ------------------------------------------------------------
# Epoch 090 | Training loss: 0.4029
# Epoch 090 | Validation loss: 0.4089
# Epoch 090 completed in 16.70s
# ------------------------------------------------------------
# Epoch 091 | Training loss: 0.4024
# Epoch 091 | Validation loss: 0.4093
# Epoch 091 completed in 16.57s
# ------------------------------------------------------------
# Epoch 092 | Training loss: 0.3995
# Epoch 092 | Validation loss: 0.4109
# Epoch 092 completed in 16.55s
# ------------------------------------------------------------
# Epoch 093 | Training loss: 0.4042
# Epoch 093 | Validation loss: 0.4110
# Epoch 093 completed in 16.69s
# ------------------------------------------------------------
# Epoch 094 | Training loss: 0.4023
# Epoch 094 | Validation loss: 0.4109
# Epoch 094 completed in 16.76s
# ------------------------------------------------------------
# Epoch 095 | Training loss: 0.4019
# Epoch 095 | Validation loss: 0.4099
# Epoch 095 completed in 16.51s
# ------------------------------------------------------------
# Epoch 096 | Training loss: 0.4042
# Epoch 096 | Validation loss: 0.4096
# Epoch 096 completed in 16.66s
# ------------------------------------------------------------
# Epoch 097 | Training loss: 0.4023
# Epoch 097 | Validation loss: 0.4097
# Epoch 097 completed in 16.62s
# ------------------------------------------------------------
# Epoch 098 | Training loss: 0.4021
# Epoch 098 | Validation loss: 0.4092
# Epoch 098 completed in 16.47s
# ------------------------------------------------------------
# Epoch 099 | Training loss: 0.3997
# Epoch 099 | Validation loss: 0.4100
# Epoch 099 completed in 16.41s
# ------------------------------------------------------------
# Epoch 100 | Training loss: 0.3987
# Epoch 100 | Validation loss: 0.4110
# Epoch 100 completed in 16.59s
# ------------------------------------------------------------
# Epoch 101 | Training loss: 0.4005
# Epoch 101 | Validation loss: 0.4106
# Epoch 101 completed in 16.58s
# ------------------------------------------------------------
# Epoch 102 | Training loss: 0.3988
# Epoch 102 | Validation loss: 0.4114
# Epoch 102 completed in 16.53s
# ------------------------------------------------------------
# Epoch 103 | Training loss: 0.4037
# Epoch 103 | Validation loss: 0.4104
# Epoch 103 completed in 16.59s
# ------------------------------------------------------------
# Epoch 104 | Training loss: 0.4019
# Epoch 104 | Validation loss: 0.4097
# Epoch 104 completed in 16.21s
# ------------------------------------------------------------
# Epoch 105 | Training loss: 0.4044
# Epoch 105 | Validation loss: 0.4093
# Epoch 105 completed in 16.52s
# ------------------------------------------------------------
# Epoch 106 | Training loss: 0.4027
# Epoch 106 | Validation loss: 0.4098
# Epoch 106 completed in 16.85s
#
# Early stopping à l'époque 106 (patience: 29)
#
# Meilleur modèle chargé (époque 77, val_loss: 0.4053)
#
# === Évaluation finale ===
# Performance sur l'ensemble de validation:
# Performance for test_dataset
# AUC-ROC: 0.8549, AUC-PR: 0.7107, Accuracy: 0.8069, B_ACC : 0.736, MCC: 0.4892, Sensitivity/Recall: 0.5848, Specificity: 0.8871, Precision: 0.6517, F1-score: 0.6164, CK-score 0.4879
# Val Performance:
#   ROC-AUC: 0.8549 | PR-AUC: 0.7107 | Accuracy: 0.8069
#   F1: 0.6164 | MCC: 0.4892 | Balanced Acc: 0.7360
#
# Performance sur l'ensemble de test:
# Performance for test_dataset
# AUC-ROC: 0.85, AUC-PR: 0.6726, Accuracy: 0.8038, B_ACC : 0.7274, MCC: 0.4772, Sensitivity/Recall: 0.5642, Specificity: 0.8906, Precision: 0.6512, F1-score: 0.6046, CK-score 0.475
# Test Performance:
#   ROC-AUC: 0.8500 | PR-AUC: 0.6726 | Accuracy: 0.8038
#   F1: 0.6046 | MCC: 0.4772 | Balanced Acc: 0.7274
#
# === Analyse d'interprétabilité ===
#
# Top 10 features importantes:
#    1. TotalCharges        : 0.0685
#    2. StreamingMovies     : 0.0668
#    3. InternetService     : 0.0657
#    4. MultipleLines       : 0.0653
#    5. OnlineBackup        : 0.0613
#    6. SeniorCitizen       : 0.0605
#    7. StreamingTV         : 0.0570
#    8. Dependents          : 0.0540
#    9. PhoneService        : 0.0520
#   10. Contract            : 0.0504
#
# Génération des visualisations...
# Graphique d'importance sauvegardé: results/results_telecom/sparse_ftt_plus/seed_0/heatmaps/interpretable_sparse_ftt_plus_importance_seed_0.png
# Avertissement: Impossible de générer la heatmap d'attention pour interpretable_sparse_ftt_plus: 'numpy.ndarray' object has no attribute 'cpu'
#
# === Résultats sauvegardés ===
# Métriques: results/results_telecom/sparse_ftt_plus/seed_0/interpretable_sparse_ftt_plus_metrics_seed_0.json
# Importance: results/results_telecom/sparse_ftt_plus/seed_0/interpretable_sparse_ftt_plus_importance_seed_0.json
# Visualisations: results/results_telecom/sparse_ftt_plus/seed_0/interpretable_sparse_ftt_plus_{importance|attention}_seed_0.png
# Modèle: results/results_telecom/sparse_ftt_plus/seed_0/interpretable_sparse_ftt_plus_weights_seed_0.pt
# Entraînement terminé!

# %% [markdown]
# ## FT-T Model Optimized with Optuna

# %%
"""
import os

# Changer vers le répertoire racine
os.chdir('/kaggle/working/customer-churn-ft_transformer')

# Utiliser PYTHONPATH pour que train.py trouve les modules
# !PYTHONPATH=/kaggle/working/customer-churn-ft_transformer python train/Telecom/train_ftt/experiment_with_optuna.py
"""
# Out:
# "\nimport os\n\n# Changer vers le répertoire racine\nos.chdir('/kaggle/working/customer-churn-ft_transformer')\n\n# Utiliser PYTHONPATH pour que train.py trouve les modules\n!PYTHONPATH=/kaggle/working/customer-churn-ft_transformer python train/Telecom/train_ftt/experiment_with_optuna.py\n"

# %% [markdown]
# ## FT-T + Model Optimized with Optuna

# %%
"""
import os

# Changer vers le répertoire racine
os.chdir('/kaggle/working/customer-churn-ft_transformer')

# Utiliser PYTHONPATH pour que train.py trouve les modules
# !PYTHONPATH=/kaggle/working/customer-churn-ft_transformer python train/Telecom/train_ftt_plus/experiment_with_optuna.py
"""
# Out:
# "\nimport os\n\n# Changer vers le répertoire racine\nos.chdir('/kaggle/working/customer-churn-ft_transformer')\n\n# Utiliser PYTHONPATH pour que train.py trouve les modules\n!PYTHONPATH=/kaggle/working/customer-churn-ft_transformer python train/Telecom/train_ftt_plus/experiment_with_optuna.py\n"

# %% [markdown]
# ## Sparse FT-T + Model Optimized with Optuna

# %%
"""
import os

# Changer vers le répertoire racine
os.chdir('/kaggle/working/customer-churn-ft_transformer')

# Utiliser PYTHONPATH pour que train.py trouve les modules
# !PYTHONPATH=/kaggle/working/customer-churn-ft_transformer python train/Telecom/train_sparse_ftt_plus/experiment_with_optuna.py
"""
# Out:
# "\nimport os\n\n# Changer vers le répertoire racine\nos.chdir('/kaggle/working/customer-churn-ft_transformer')\n\n# Utiliser PYTHONPATH pour que train.py trouve les modules\n!PYTHONPATH=/kaggle/working/customer-churn-ft_transformer python train/Telecom/train_sparse_ftt_plus/experiment_with_optuna.py\n"

# %% [markdown]
# # Downloading the results folder

# %%
# !pwd
# !ls -la
# Out:
# /kaggle/working/customer-churn-ft_transformer
# total 5924
# drwxr-xr-x 11 root root    4096 Jul 31 17:56 .
# drwxr-xr-x  3 root root    4096 Jul 31 17:53 ..
# drwxr-xr-x  3 root root    4096 Jul 31 17:53 data
# -rw-r--r--  1 root root 5962887 Jul 31 17:53 Experiments.ipynb
# drwxr-xr-x  3 root root    4096 Jul 31 17:56 ftt_plus
# drwxr-xr-x  8 root root    4096 Jul 31 17:53 .git
# -rw-r--r--  1 root root     686 Jul 31 17:53 .gitignore
# drwxr-xr-x  2 root root    4096 Jul 31 17:53 images
# -rw-r--r--  1 root root   10781 Jul 31 17:53 interpretability_analyzer.py
# -rw-r--r--  1 root root   10266 Jul 31 17:53 num_embedding_factory.py
# drwxr-xr-x  2 root root    4096 Jul 31 17:56 __pycache__
# -rw-r--r--  1 root root    6424 Jul 31 17:53 README.md
# drwxr-xr-x  4 root root    4096 Jul 31 19:02 results
# drwxr-xr-x  5 root root    4096 Jul 31 17:53 rtdl_lib
# drwxr-xr-x  3 root root    4096 Jul 31 18:21 sparse_ftt_plus
# -rw-r--r--  1 root root    6821 Jul 31 17:53 test_embeddings.py
# drwxr-xr-x  4 root root    4096 Jul 31 17:53 train
# -rw-r--r--  1 root root    2333 Jul 31 17:53 utils.py
# -rw-r--r--  1 root root    5340 Jul 31 17:53 visualisation.py

# %%
import shutil

# On se place dans le bon dossier racine
import os
os.chdir('/kaggle/working/customer-churn-ft_transformer')

# On crée une archive ZIP du dossier results
shutil.make_archive('/kaggle/working/results', 'zip', 'results')
# Out:
# '/kaggle/working/results.zip'
